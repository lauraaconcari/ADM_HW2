# %%
#!wget -P "/content/drive/MyDrive/Colab Notebooks" https://www.kaggle.com/datasets/opalskies/large-books-metadata-dataset-50-mill-entries/download?datasetVersionNumber=3

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
filename = "/content/drive/MyDrive/Colab Notebooks/lighter_authors.json"
filename1 = "/content/drive/MyDrive/Colab Notebooks/lighter_books.json"
filename2 = "/content/drive/MyDrive/Colab Notebooks/list.json"

# %% [markdown]
# ## Tests

# %%
# Read the data
df_chunks = pd.read_json(filename1, lines=True, chunksize=200000)

# Create an empty DataFrame to store the results
df1 = pd.DataFrame()

# Loop through each chunk and append it to the result DataFrame
for chunk in df_chunks:
    chunk = chunk['author_name']
    df1 = pd.concat([df1, chunk], ignore_index=True)

# %%
# Read the data
df_chunks = pd.read_json(filename, lines=True, dtype={'ratings_count': 'int32', 'text_reviews_count':'int32',
            'works_count':'int32', 'id':'int32', 'fans_count':'int32', 'name':'string', 'gender':'string', 'image_url':'string', 'average_rating':'float16', 'about':'string'}, chunksize=10000)

# Create an empty DataFrame to store the results
df = pd.DataFrame()

# Loop through each chunk and append it to the result DataFrame
for chunk in df_chunks:
    df = pd.concat([df, chunk], ignore_index=True)

# %%
df.head()
# Out:
#    ratings_count  average_rating  text_reviews_count  \
# 0        2862064        4.191406               62681
# 1        1417316        4.019531               84176
# 2          56159        4.531250                 352
# 3           3302        3.789062                 480
# 4           7979        3.599609                 772
#
#                                             work_ids  \
# 0  [3078186, 135328, 1877624, 74123, 3078120, 104...
# 1  [613469, 2305997, 940892, 2611786, 7800569, 31...
# 2  [17150, 808427, 20487307, 90550, 25460625, 171...
# 3  [4417, 14300808, 14780, 3796968, 44703121, 103...
# 4  [13330815, 19109351, 42306244, 72694240, 26291...
#
#                                             book_ids  works_count  id  \
# 0  [386162, 13, 8695, 8694, 6091075, 365, 569429,...          106   4
# 1  [9791, 21, 28, 24, 7507825, 27, 10538, 25, 26,...           75   7
# 2  [349254, 15222, 14833682, 15221, 18126815, 152...           14  10
# 3  [40, 9416484, 12482, 3753106, 26889789, 104764...           45  12
# 4  [8466327, 15739968, 22756778, 51026133, 260451...           61  14
#
#                       name  gender  \
# 0            Douglas Adams    male
# 1              Bill Bryson    male
# 2              Jude Fisher  female
# 3  James Hamilton-Paterson    male
# 4              Mark Watson    male
#
#                                            image_url  \
# 0  https://images.gr-assets.com/authors/159137433...
# 1  https://images.gr-assets.com/authors/157859752...
# 2  https://images.gr-assets.com/authors/141145711...
# 3  https://images.gr-assets.com/authors/127051738...
# 4  https://images.gr-assets.com/authors/133175379...
#
#                                                about  fans_count
# 0  Douglas Noël Adams was an English author, comi...       19826
# 1  William McGuire "Bill" Bryson, OBE, FRS was bo...       16144
# 2  Jude Fisher is the pseudonym for <a href="http...          60
# 3  James Hamilton-Paterson's work has been transl...          72
# 4  Mark Andrew Watson (born 13 February 1980) is ...         179

# %%
d = pd.read_json(filename1, lines=True, nrows=100)
d.language.value_counts()
dd = pd.Series(d.language.value_counts()).append(d.language.value_counts()).to_frame().reset_index()
result = dd.groupby('index').sum()
result
# Out:
# <ipython-input-56-5099124c8420>:3: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dd = pd.Series(d.language.value_counts()).append(d.language.value_counts()).to_frame().reset_index()
#        language
# index
#              30
# en-US        12
# eng         152
# fre           2
# spa           4

# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.0.tar.gz (316.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.9/316.9 MB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.0-py2.py3-none-any.whl size=317425344 sha256=a3cbdca54f614e61c332ba23d220fb1c5b8d8379da296164fd1ecbbd7d4f4c37
#   Stored in directory: /root/.cache/pip/wheels/41/4e/10/c2cf2467f71c678cfc8a6b9ac9241e5e44a01940da8fbb17fc
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.0

# %%
from pyspark import SparkContext
from pyspark.sql import SparkSession

sc = SparkContext("local", "YourAppName")
spark = SparkSession(sc)

# %%
df = spark.read.json(filename)
df

# %%
specific_row = df.filter(df["title"] == "Pride and Prejudice")

# Show the specific row
specific_row.show(40)
# Out:
# +----+---------+-----------+--------------------+--------------+--------------------+--------------------+--------------------+------+--------------------+----------+-------------+--------+---------+-------------------------+----------------+--------------------+--------------------+-------------+---------+-----------+---------------+--------------------+------------------+-------------------+-------+
# |asin|author_id|author_name|             authors|average_rating|         description| edition_information|              format|    id|           image_url|      isbn|       isbn13|language|num_pages|original_publication_date|publication_date|           publisher|         rating_dist|ratings_count|series_id|series_name|series_position|             shelves|text_reviews_count|              title|work_id|
# +----+---------+-----------+--------------------+--------------+--------------------+--------------------+--------------------+------+--------------------+----------+-------------+--------+---------+-------------------------+----------------+--------------------+--------------------+-------------+---------+-----------+---------------+--------------------+------------------+-------------------+-------+
# |    |     1265|Jane Austen|[{1265, Jane Aust...|          4.27|<i>Alternate cove...|Modern Library Cl...|           Paperback|  1885|https://i.gr-asse...|          |             |     eng|      279|               1813-01-28|      2000-10-10|      Modern Library|5:1709563|4:85571...|      3152481|         |           |               |[{1368120, to-rea...|             71971|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|[{1265, Jane Aust...|          4.27|<i>Alternate-cove...|                    |           Paperback|  1886|https://i.gr-asse...|          |             |     eng|      367|               1813-01-28|            2003|    Penguin Classics|5:1690515|4:84691...|      3119654|         |           |               |[{1343581, to-rea...|             68274|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|                NULL|          4.27|Pride and Prejudi...|Oxford World Clas...|           Paperback|  1888|https://i.gr-asse...|0192802380|9780192802385|     eng|      333|               1813-01-28|      2004-02-11|Oxford University...|5:1690515|4:84691...|      3119654|         |           |               |[{1343581, to-rea...|             68274|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|[{1265, Jane Aust...|          4.27|This Dover ed. is...|                    |           Hardcover|  1891|https://i.gr-asse...|0486440915|9780486440910|     eng|      476|               1813-01-28|      2005-05-05|  Dover Publications|5:1690515|4:84691...|      3119654|         |           |               |[{1343581, to-rea...|             68274|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|[{1265, Jane Aust...|          4.27|Set in England in...|                    |           Hardcover|  1893|https://s.gr-asse...|1593083246|9781593083243|     eng|      392|               1813-01-28|      2004-09-20|Barnes  Noble Cla...|5:1690515|4:84691...|      3119654|         |           |               |[{1343581, to-rea...|             68274|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|[{1265, Jane Aust...|          4.27|One of the best-l...|Cover to cover cl...|            Audio CD|  2150|https://s.gr-asse...|1572705000|9781572705005|     eng|     NULL|               1813-01-28|      2005-10-06|      Audio Partners|5:1690515|4:84691...|      3119654|         |           |               |[{1343581, to-rea...|             68274|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|                NULL|          4.27|Set in England in...|                    |                    |  2565|https://s.gr-asse...|1576462676|9781576462676|        |     NULL|               1813-01-28|                |                    |5:1690515|4:84691...|      3119654|         |           |               |[{1343581, to-rea...|             68274|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|                NULL|          4.27|There are five da...|Penguin Popular C...|Mass Market Paper...|  4615|https://i.gr-asse...|0140620222|9780140620221|     eng|      299|               1813-01-28|            1994|             Penguin|5:1687877|4:84528...|      3114732|         |           |               |[{1343581, to-rea...|             68827|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|                NULL|          4.26|Mr. Bennet's five...|         Large Print|           Hardcover| 14911|https://i.gr-asse...|070898228X|9780708982280|     eng|      533|               1813-01-28|      1984-12-01|           Charnwood|5:1633636|4:82344...|      3025427|         |           |               |[{1258196, to-rea...|             68060|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|[{1265, Jane Aust...|          4.26|'It is a truth un...|The Cambridge Edi...|           Hardcover| 14914|https://s.gr-asse...|0521825148|9780521825146|     eng|      540|               1813-01-28|      2006-07-01|Cambridge Univers...|5:1633636|4:82344...|      3025427|         |           |               |[{1258196, to-rea...|             68060|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|                NULL|          4.26|It is a truth uni...|                    |           Hardcover| 14918|https://i.gr-asse...|080959630X|9780809596300|        |      348|               1813-01-28|      2004-02-01|      Wildside Press|5:1633636|4:82344...|      3025427|         |           |               |[{1258196, to-rea...|             68060|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|[{1265, Jane Aust...|          4.26|Many consider thi...|Barnes &amp; Nobl...|                    | 14919|https://s.gr-asse...|0760748683|9780760748688|     eng|     NULL|               1813-01-28|                |            Sterling|5:1633636|4:82344...|      3025427|         |           |               |[{1258196, to-rea...|             68060|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|                NULL|          4.26|Elizabeth Bennet ...|                    |           Hardcover| 14920|https://s.gr-asse...|1404324844|9781404324848|        |      344|               1813-01-28|      2002-09-01|     IndyPublish.com|5:1633636|4:82344...|      3025427|         |           |               |[{1258196, to-rea...|             68060|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|[{1265, Jane Aust...|          4.26|A delightful nove...|                    |            Audio CD| 14923|https://s.gr-asse...|0786178485|9780786178483|        |       11|               1813-01-28|      2005-04-01|Blackstone Audiob...|5:1633636|4:82344...|      3025427|         |           |               |[{1258196, to-rea...|             68060|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|[{1265, Jane Aust...|          4.27|For almost 200 ye...|   Enriched Classics|Mass Market Paper...| 50380|https://i.gr-asse...|0743487591|9780743487597|     eng|      458|               1813-01-28|      2004-05-01|    Simon & Schuster|5:1686582|4:84470...|      3112499|         |           |               |[{50039, classics...|             68711|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|[{1265, Jane Aust...|          4.26|An Authoritative ...|Norton Critical E...|           Paperback| 76694|https://i.gr-asse...|0393096688|9780393096682|        |      450|               1813-01-28|      1966-06-01|W. W. Norton & Co...|5:1633694|4:82348...|      3025546|         |           |               |[{1258196, to-rea...|             68061|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|                NULL|          4.26|<a href="https://...|      Bantam Classic|           Paperback| 84979|https://i.gr-asse...|0553213105|9780553213102|     eng|      334|               1813-01-28|         2003-03|      Bantam Classic|5:1633705|4:82349...|      3025562|         |           |               |[{1258196, to-rea...|             68061|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|[{1265, Jane Aust...|          4.26|<b>Top 5 Finalist...|                    |            Audio CD|110803|https://s.gr-asse...|1597371416|9781597371414|        |     NULL|               1813-01-28|      2005-08-25|    Brilliance Audio|5:1633714|4:82349...|      3025578|         |           |               |[{1258196, to-rea...|             68061|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|                NULL|          4.26|Austen, Jane "Pri...|                    |           Hardcover|110805|https://s.gr-asse...|1933652446|9781933652443|        |      264|               1813-01-28|      2005-11-07|            Bed Book|5:1633714|4:82349...|      3025578|         |           |               |[{1258196, to-rea...|             68061|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|[{1265, Jane Aust...|          4.26|'It is a truth un...|Barnes &amp; Nobl...|           Paperback|110806|https://i.gr-asse...|1593080204|9781593080204|     eng|      376|               1813-01-28|      2003-08-01|Barnes & Noble Cl...|5:1633714|4:82349...|      3025578|         |           |               |[{1258196, to-rea...|             68061|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|[{1265, Jane Aust...|          4.26|Jane Austen's mos...|          Unabridged|           Audiobook|110807|https://i.gr-asse...|9626343567|9789626343562|     eng|       11|               1813-01-28|      2005-03-30|    Naxos Audiobooks|5:1633714|4:82349...|      3025578|         |           |               |[{1258196, to-rea...|             68061|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|[{1265, Jane Aust...|          4.26|When Elizabeth Be...|                    |            Audio CD|110809|https://i.gr-asse...|0141804459|9780141804453|     eng|     NULL|               1813-01-28|      2003-01-30|             Penguin|5:1633714|4:82349...|      3025578|         |           |               |[{1258196, to-rea...|             68061|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|[{1265, Jane Aust...|          4.26|"It is a truth un...|Barnes &amp; Nobl...|           Paperback|110810|https://i.gr-asse...|1593082010|9781593082017|        |      392|               1813-01-28|      2004-05-14|      Barnes & Noble|5:1633714|4:82349...|      3025578|         |           |               |[{1258196, to-rea...|             68061|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|[{1265, Jane Aust...|          4.26|<b>Jane Austen's ...|                    |               Audio|110813|https://s.gr-asse...|1590861515|9781590861516|        |     NULL|               1813-01-28|      2002-06-28|    Brilliance Audio|5:1633714|4:82349...|      3025578|         |           |               |[{1258196, to-rea...|             68061|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|[{1265, Jane Aust...|          4.26|From Longman's Cu...|A Longman Cultura...|           Paperback|110814|https://s.gr-asse...|0321105079|9780321105073|     eng|      496|               1813-01-28|            2003|             Pearson|5:1633714|4:82349...|      3025578|         |           |               |[{1258196, to-rea...|             68061|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|                NULL|          4.26|Set in England in...|Barnes &amp; Nobl...|                    |110819|https://s.gr-asse...|1566190932|9781566190930|     eng|     NULL|               1813-01-28|                |            Sterling|5:1633714|4:82349...|      3025578|         |           |               |[{1258196, to-rea...|             68061|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|                NULL|          4.26|Five vivacious si...|         Large Print|           Paperback|110820|https://i.gr-asse...|0486417751|9780486417752|     eng|      480|               1813-01-28|      2001-05-14|  Dover Publications|5:1633714|4:82349...|      3025578|         |           |               |[{1258196, to-rea...|             68061|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|                NULL|          4.26|"It is a truth un...|                    |           Hardcover|110821|https://i.gr-asse...|1904633013|9781904633013|   en-US|      482|               1813-01-28|      2009-10-01| Collector's Library|5:1633714|4:82349...|      3025578|         |           |               |[{1258196, to-rea...|             68061|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|                NULL|          4.26|Set in England in...|                    |           Paperback|110823|https://s.gr-asse...|014130930X|9780141309309|        |      384|               1813-01-28|      2000-07-01|              Puffin|5:1633714|4:82349...|      3025578|         |           |               |[{1258196, to-rea...|             68061|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|[{1265, Jane Aust...|          4.26|6 CDs, 5 1/2 hour...|Penguin Classics,...|            Audio CD|110827|https://i.gr-asse...|0143058177|9780143058175|     eng|        6|               1813-01-28|            1994|  Penguin Audiobooks|5:1633714|4:82349...|      3025578|         |           |               |[{1258196, to-rea...|             68061|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|[{1265, Jane Aust...|          4.26|A perennial favor...|Second Norton Cri...|           Paperback|110828|https://s.gr-asse...|0393962946|9780393962949|     eng|      388|               1813-01-28|      1993-04-01|W. W. Norton & Co...|5:1633714|4:82349...|      3025578|         |           |               |[{1258196, to-rea...|             68061|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|                NULL|          4.26|Set in England in...|Literary Touchsto...|                    |110833|https://s.gr-asse...|1580495990|9781580495998|     eng|     NULL|               1813-01-28|                |                    |5:1633714|4:82349...|      3025578|         |           |               |[{1258196, to-rea...|             68061|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|                NULL|          4.26|In early nineteen...|         Large Print|           Paperback|110834|https://i.gr-asse...|1426455372|9781426455377|        |      384|               1813-01-28|            2006|          BiblioLife|5:1633714|4:82349...|      3025578|         |           |               |[{1258196, to-rea...|             68061|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|                NULL|          4.26|This is a pre-192...|                    |           Paperback|110841|https://s.gr-asse...|1426455089|9781426455087|        |      348|               1813-01-28|      2008-05-29|          BiblioLife|5:1633714|4:82349...|      3025578|         |           |               |[{1258196, to-rea...|             68061|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|                NULL|          4.26|“I had not known ...|                    |           Paperback|110844|https://i.gr-asse...|075533146X|9780755331468|     eng|      390|               1813-01-28|      2006-05-15|     Headline Review|5:1633714|4:82349...|      3025578|         |           |               |[{1258196, to-rea...|             68061|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|                NULL|          4.26|Acclaimed by one ...|                    |            Audio CD|110845|https://s.gr-asse...|1584723947|9781584723943|        |     NULL|               1813-01-28|      2008-10-01|            In Audio|5:1633714|4:82349...|      3025578|         |           |               |[{1258196, to-rea...|             68061|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|[{1265, Jane Aust...|          4.26|'It is a truth un...|                    |           Hardcover|110847|https://s.gr-asse...|0531169944|9780531169940|        |      354|               1813-01-28|      2007-01-31|    Children's Press|5:1633714|4:82349...|      3025578|         |           |               |[{1258196, to-rea...|             68061|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|[{1265, Jane Aust...|          4.26|Elizabeth Bennet ...|                    |           Paperback|110848|https://s.gr-asse...|1551110288|9781551110288|     eng|      493|               1813-01-28|            2002|Broadview Literar...|5:1633714|4:82349...|      3025578|         |           |               |[{1258196, to-rea...|             68061|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|[{1265, Jane Aust...|          4.26|<b>Jane Austen's ...|                    |            Audio CD|110850|https://s.gr-asse...|1593351917|9781593351915|        |     NULL|               1813-01-28|      2004-06-10|    Brilliance Audio|5:1633714|4:82349...|      3025578|         |           |               |[{1258196, to-rea...|             68061|Pride and Prejudice|3060926|
# |    |     1265|Jane Austen|[{1265, Jane Aust...|          4.26|Set in England in...|                    |            Audio CD|110851|https://s.gr-asse...|078619894X|9780786198948|     eng|     NULL|               1813-01-28|                |                    |5:1633714|4:82349...|      3025578|         |           |               |[{1258196, to-rea...|             68061|Pride and Prejudice|3060926|
# +----+---------+-----------+--------------------+--------------+--------------------+--------------------+--------------------+------+--------------------+----------+-------------+--------+---------+-------------------------+----------------+--------------------+--------------------+-------------+---------+-----------+---------------+--------------------+------------------+-------------------+-------+
# only showing top 40 rows

# %%
df.show()
# Out:
# +--------------------+--------------+--------------------+----------+------+---+--------------------+--------------------+-------------+------------------+--------------------+-----------+
# |               about|average_rating|            book_ids|fans_count|gender| id|           image_url|                name|ratings_count|text_reviews_count|            work_ids|works_count|
# +--------------------+--------------+--------------------+----------+------+---+--------------------+--------------------+-------------+------------------+--------------------+-----------+
# |Douglas Noël Adam...|          4.19|[386162, 13, 8695...|     19826|  male|  4|https://images.gr...|       Douglas Adams|      2862064|             62681|[3078186, 135328,...|        106|
# |William McGuire "...|          4.02|[9791, 21, 28, 24...|     16144|  male|  7|https://images.gr...|         Bill Bryson|      1417316|             84176|[613469, 2305997,...|         75|
# |Jude Fisher is th...|          4.53|[349254, 15222, 1...|        60|female| 10|https://images.gr...|         Jude Fisher|        56159|               352|[17150, 808427, 2...|         14|
# |James Hamilton-Pa...|          3.79|[40, 9416484, 124...|        72|  male| 12|https://images.gr...|James Hamilton-Pa...|         3302|               480|[4417, 14300808, ...|         45|
# |Mark Andrew Watso...|           3.6|[8466327, 1573996...|       179|  male| 14|https://images.gr...|         Mark Watson|         7979|               772|[13330815, 191093...|         61|
# |Edith Newbold Jon...|          3.78|[53835, 5246, 177...|      3179|female| 16|https://images.gr...|       Edith Wharton|       436635|             26193|[1959512, 132919,...|       1001|
# |<a target="_blank...|          4.59|[49, 20035, 10703...|        10|  male| 17|https://images.gr...|       Luther Butler|           46|                21|[4420, 21232, 105...|         36|
# |Although he was n...|          3.79|[50, 141372, 2915...|      2636|  male| 18|https://images.gr...|        Gary Paulsen|       503435|             34364|[1158125, 241811,...|        226|
# |Dale Peck (born 1...|          3.66|[6217775, 19979, ...|        99|      | 20|https://images.gr...|           Dale Peck|         6392|               631|[6398423, 21178, ...|         26|
# |Angela Knight is ...|           4.0|[1708127, 7044446...|       963|      | 23|https://images.gr...|       Angela Knight|       100211|              3650|[1705297, 7294256...|         99|
# |Delia Sherman (bo...|          3.91|[92377, 9727730, ...|       302|female| 24|https://images.gr...|       Delia Sherman|        58429|              5379|[460093, 14616573...|        124|
# |Patricia Anne McK...|          3.99|[81069, 92755, 19...|      2206|female| 25|https://images.gr...|Patricia A. McKillip|       145505|              9638|[2934, 1711249, 7...|         96|
# |Anne McCaffrey wa...|          4.08|[61975, 28541, 12...|      6444|female| 26|https://images.gr...|      Anne McCaffrey|      1105819|             23112|[2467422, 1171182...|        336|
# |The recipient of ...|          3.83|[903, 2316, 81010...|       362|female| 27|https://images.gr...|Zilpha Keatley Sn...|        53861|              3403|[1731888, 1550961...|         60|
# |Born in Richmond,...|           3.8|[20059, 63, 19514...|        41|female| 29|https://images.gr...|        Kate Horsley|         2815|               413|[21256, 4431, 212...|         10|
# |<i>Librarian Note...|          3.81|[266782, 291514, ...|       423|female| 31|https://images.gr...|   Elaine Cunningham|        42412|               939|[522983, 2179204,...|         99|
# |Eleanor Alice Bur...|          3.88|[349272, 817235, ...|       183|female| 32|https://images.gr...|       Philippa Carr|        11256|               500|[3158204, 1830669...|         41|
# |Edward P. Jones h...|          3.85|[3319095, 67, 135...|       496|  male| 33|https://images.gr...|     Edward P. Jones|        48085|              4543|[2063986, 1062798...|         21|
# |Satyajit Das is a...|          3.73|[15818399, 71, 11...|        49|  male| 36|https://images.gr...|        Satyajit Das|         4367|               379|[21546017, 4436, ...|         31|
# |While <i>The Barr...|          3.84|[18050226, 19961,...|       141|  male| 38|https://s.gr-asse...|         Mark Smylie|         5188|               582|[25333032, 21160,...|         43|
# +--------------------+--------------+--------------------+----------+------+---+--------------------+--------------------+-------------+------------------+--------------------+-----------+
# only showing top 20 rows

# %% [markdown]
# # RQ1

# %% [markdown]
# ### Authors

# %%
# Read the authors data
df = pd.read_json(filename, lines=True)
print(df.info(), df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351767 entries, 0 to 351766
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ratings_count       351767 non-null  int64
#  1   average_rating      351767 non-null  float64
#  2   text_reviews_count  351767 non-null  int64
#  3   work_ids            351767 non-null  object
#  4   book_ids            351767 non-null  object
#  5   works_count         351767 non-null  int64
#  6   id                  351767 non-null  int64
#  7   name                351767 non-null  object
#  8   gender              351767 non-null  object
#  9   image_url           351767 non-null  object
#  10  about               351767 non-null  object
#  11  fans_count          351767 non-null  int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 32.2+ MB
# None        ratings_count  average_rating  text_reviews_count   works_count  \
# count   3.517670e+05   351767.000000       351767.000000  3.517670e+05
# mean    4.770586e+03        3.651194          330.993243  2.593714e+01
# std     9.769395e+04        1.211482         3857.539191  3.066083e+03
# min    -4.100000e+01      -31.000000            0.000000  0.000000e+00
# 25%     6.000000e+00        3.600000            1.000000  2.000000e+00
# 50%     3.900000e+01        3.950000            8.000000  6.000000e+00
# 75%     3.100000e+02        4.250000           53.000000  1.500000e+01
# max     2.700375e+07        5.000000       608956.000000  1.775176e+06
#
#                  id     fans_count
# count  3.517670e+05  351767.000000
# mean   7.751861e+06     111.615731
# std    6.578409e+06    2661.018139
# min    4.000000e+00     -33.000000
# 25%    1.535315e+06       1.000000
# 50%    6.470396e+06       4.000000
# 75%    1.434041e+07      20.000000
# max    2.124802e+07  766035.000000

# %%
#Define dtypes for dataframe
dtypes={'ratings_count': 'int32', 'text_reviews_count':'int32',
        'works_count':'int32', 'id':'string', 'fans_count':'int32',
        'name':'string', 'gender':'string', 'image_url':'string', 'average_rating':'float16',
        'about':'string'}

# %%
# Reduce memory usage casting more efficent data types
df = pd.read_json(filename, lines=True, dtype=dtypes)

# Ensure memory usage decreased and values stayed the same
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351767 entries, 0 to 351766
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ratings_count       351767 non-null  int32
#  1   average_rating      351767 non-null  float16
#  2   text_reviews_count  351767 non-null  int32
#  3   work_ids            351767 non-null  object
#  4   book_ids            351767 non-null  object
#  5   works_count         351767 non-null  int32
#  6   id                  351767 non-null  string
#  7   name                351767 non-null  string
#  8   gender              351767 non-null  string
#  9   image_url           351767 non-null  string
#  10  about               351767 non-null  string
#  11  fans_count          351767 non-null  int32
# dtypes: float16(1), int32(4), object(2), string(5)
# memory usage: 24.8+ MB
# None
#        ratings_count  average_rating  text_reviews_count   works_count  \
# count   3.517670e+05   351767.000000       351767.000000  3.517670e+05
# mean    4.770586e+03             NaN          330.993243  2.593714e+01
# std     9.769395e+04        0.000000         3857.539191  3.066083e+03
# min    -4.100000e+01      -31.000000            0.000000  0.000000e+00
# 25%     6.000000e+00        3.599609            1.000000  2.000000e+00
# 50%     3.900000e+01        3.949219            8.000000  6.000000e+00
# 75%     3.100000e+02        4.250000           53.000000  1.500000e+01
# max     2.700375e+07        5.000000       608956.000000  1.775176e+06
#
#           fans_count
# count  351767.000000
# mean      111.615731
# std      2661.018139
# min       -33.000000
# 25%         1.000000
# 50%         4.000000
# 75%        20.000000
# max    766035.000000

# %%
df.head()
# Out:
#    ratings_count  average_rating  text_reviews_count  \
# 0        2862064        4.191406               62681
# 1        1417316        4.019531               84176
# 2          56159        4.531250                 352
# 3           3302        3.789062                 480
# 4           7979        3.599609                 772
#
#                                             work_ids  \
# 0  [3078186, 135328, 1877624, 74123, 3078120, 104...
# 1  [613469, 2305997, 940892, 2611786, 7800569, 31...
# 2  [17150, 808427, 20487307, 90550, 25460625, 171...
# 3  [4417, 14300808, 14780, 3796968, 44703121, 103...
# 4  [13330815, 19109351, 42306244, 72694240, 26291...
#
#                                             book_ids  works_count  id  \
# 0  [386162, 13, 8695, 8694, 6091075, 365, 569429,...          106   4
# 1  [9791, 21, 28, 24, 7507825, 27, 10538, 25, 26,...           75   7
# 2  [349254, 15222, 14833682, 15221, 18126815, 152...           14  10
# 3  [40, 9416484, 12482, 3753106, 26889789, 104764...           45  12
# 4  [8466327, 15739968, 22756778, 51026133, 260451...           61  14
#
#                       name  gender  \
# 0            Douglas Adams    Male
# 1              Bill Bryson    Male
# 2              Jude Fisher  Female
# 3  James Hamilton-Paterson    Male
# 4              Mark Watson    Male
#
#                                            image_url  \
# 0  https://images.gr-assets.com/authors/159137433...
# 1  https://images.gr-assets.com/authors/157859752...
# 2  https://images.gr-assets.com/authors/141145711...
# 3  https://images.gr-assets.com/authors/127051738...
# 4  https://images.gr-assets.com/authors/133175379...
#
#                                                about  fans_count
# 0  Douglas Noël Adams was an English author, comi...       19826
# 1  William McGuire "Bill" Bryson, OBE, FRS was bo...       16144
# 2  Jude Fisher is the pseudonym for <a href="http...          60
# 3  James Hamilton-Paterson's work has been transl...          72
# 4  Mark Andrew Watson (born 13 February 1980) is ...         179

# %%
# Check unique values
genders = df['gender'].unique()
names = df['name'].unique()
ids = df['id'].unique()

# %%
print('All unique gender values in the data set: ', genders)
print('Total number of unique gender values: ', len(genders))
# Out:
# All unique gender values in the data set:  ['Male' 'Female' 'Other' 'Non-binary']
# Total number of unique gender values:  4

# %%
print('Number of unique author ids: ', len(ids))
print('Number of unique author names: ',len(names))
# Out:
# Number of unique author ids:  351767
# Number of unique author names:  351730

# %% [markdown]
# It's best to use author ids since ther are some cases of eponymous

# %%
# Verify if there are any missing data
missing = df.isna().sum()
# Check for empty values
empty = df[df == ''].count()

print('Missing data:\n', missing)
print('\nEmpty data:\n', empty)
# Out:
# Missing data:
#  ratings_count         0
# average_rating        0
# text_reviews_count    0
# work_ids              0
# book_ids              0
# works_count           0
# id                    0
# name                  0
# gender                0
# image_url             0
# about                 0
# fans_count            0
# dtype: int64
#
# Empty data:
#  ratings_count              0
# average_rating             0
# text_reviews_count         0
# work_ids                   0
# book_ids                   0
# works_count                0
# id                         0
# name                       0
# gender                103377
# image_url                  0
# about                      0
# fans_count                 0
# dtype: int64

# %% [markdown]
# Handle genders by creating a mapping to 4 categories

# %%
print(len(df[df.gender == 'female'] == True))
print(len(df[df.gender == 'male'] == True))
# Out:
# 109878
# 138179

# %%
# Define category mappings
category_mapping = {
    # Male Genders
    'Male': {
        'Male', 'male', 'man', 'Man'
    },

    # Female Genders
    'Female': {
        'Female', 'Woman', 'Femme', 'She/Her/Hers', 'female'
    },

    # Non-binary Genders
    'Queer': {
        'Non-binary', 'Non-binary (multiple instances)', 'Non binary', 'Non-Binary', 'Non-binary Woman',
        'Nonbinary', 'Nonbinary Woman', 'Nonbinary genderfluid', 'Non-binary genderqueer', 'Non-binary trans guy',
        'Non-binary/transmasculine', 'Non-binary Transgender', 'Non-Binary Transgender', 'Non binary trans person', 'Non binary trans woman',
        'Non-binary Transmasculine', 'Non-Binary Woman', 'Bigender', 'Bigender (female and agender)', 'Two-spirit', 'Agender',
        'Genderqueer', 'Genderqueer transfemme', 'Genderqueer Femme', 'Genderqueer genderfluid', 'Genderqueer non-binary',
        'Genderqueer transfeminine', 'Gender Non-Conforming', 'Genderless', 'Androgynous', 'Transmasculine non-binary', 'Transfemale', 'Transgender female',
        'Transfeminine', 'Trans-female', 'Transwoman', 'Trans woman', 'Trans man', 'Male (FtM)', 'Trans-Male', 'Transman',
        'Transmasculine', 'Trans male', 'Transgender male', 'FtM',
    },
}

# %%
def update_gender(gender):
    for new_gender, mappings in category_mapping.items():
        if gender in mappings:
            return new_gender
    return 'Other'  # Assign to 'Other' if not found in any category

# Apply the custom function to update the genders
df['gender'] = df['gender'].apply(update_gender)

# %%
print(len(df[df.gender == 'Female'] == True))
print(len(df[df.gender == 'Male'] == True))
# Out:
# 109883
# 138183

# %% [markdown]
# ### Books

# %%
# Peek into the dataset by looking at the first 100 rows
df_chunks = pd.read_json(filename1, lines=True, nrows=100)
df_chunks.head()
# Out:
#    id                                              title  \
# 0   2  Harry Potter and the Order of the Phoenix (Har...
# 1   3  Harry Potter and the Sorcerer's Stone (Harry P...
# 2   4  Harry Potter and the Chamber of Secrets (Harry...
# 3   5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4   6  Harry Potter and the Goblet of Fire (Harry Pot...
#
#                                              authors   author_name  author_id  \
# 0  [{'id': '1077326', 'name': 'J.K. Rowling', 'ro...  J.K. Rowling    1077326
# 1  [{'id': '1077326', 'name': 'J.K. Rowling', 'ro...  J.K. Rowling    1077326
# 2                                               None  J.K. Rowling    1077326
# 3  [{'id': '1077326', 'name': 'J.K. Rowling', 'ro...  J.K. Rowling    1077326
# 4  [{'id': '1077326', 'name': 'J.K. Rowling', 'ro...  J.K. Rowling    1077326
#
#    work_id        isbn         isbn13 asin language  ...  \
# 0  2809203  0439358078  9780439358071           eng  ...
# 1  4640799                                      eng  ...
# 2  6231171  0439554896  9780439554893           eng  ...
# 3  2402163  043965548X  9780439655484           eng  ...
# 4  3046572                                      eng  ...
#
#                   format                       edition_information  \
# 0              Paperback                                US Edition
# 1              Hardcover                           Library Edition
# 2              Hardcover
# 3  Mass Market Paperback
# 4              Paperback  First Scholastic Trade Paperback Edition
#
#                                            image_url        publisher  \
# 0  https://i.gr-assets.com/images/S/compressed.ph...  Scholastic Inc.
# 1  https://i.gr-assets.com/images/S/compressed.ph...   Scholastic Inc
# 2  https://i.gr-assets.com/images/S/compressed.ph...       Scholastic
# 3  https://i.gr-assets.com/images/S/compressed.ph...  Scholastic Inc.
# 4  https://i.gr-assets.com/images/S/compressed.ph...       Scholastic
#
#   num_pages series_id   series_name series_position  \
# 0       870     45175  Harry Potter               5
# 1       309     45175  Harry Potter               1
# 2       352     45175  Harry Potter               2
# 3       435     45175  Harry Potter               3
# 4       734     45175  Harry Potter               4
#
#                                              shelves  \
# 0  [{'name': 'to-read', 'count': 324191}, {'name'...
# 1  [{'name': 'fantasy', 'count': 63540}, {'name':...
# 2  [{'name': 'to-read', 'count': 282341}, {'name'...
# 3  [{'name': 'to-read', 'count': 292815}, {'name'...
# 4  [{'name': 'to-read', 'count': 287086}, {'name'...
#
#                                          description
# 0  There is a door at the end of a silent corrido...
# 1  Harry Potter's life is miserable. His parents ...
# 2  The Dursleys were so mean and hideous that sum...
# 3  For twelve long years, the dread fortress of A...
# 4  Harry Potter is midway through his training as...
#
# [5 rows x 26 columns]

# %%
# Set chunk size. By reading online it seems a good rule of thumb is to choose a chunksize around 10.000.
chunk_size = 100_000
# Set the dtypes for more efficient memory usage
dtype_mapping = {
    'id': 'int32',
    'author_id': 'int32',
    'work_id': 'int32',
    'ratings_count': 'int32',
    'text_reviews_count': 'int32',
    'average_rating': 'float16',
}

# %%
# Read boook file
with pd.read_json(filename1, lines=True, chunksize=chunk_size, dtype=dtype_mapping) as df_chunks:
   # Initialize variables to store chunk info
    info = {}
    # Initialize variable for total memory usage
    total_memory_usage = 0

   # Process each chunk and gather information
    for chunk in df_chunks:

        memory_usage = chunk.memory_usage(deep=True).sum()  # Compute memory usage for the current chunk
        total_memory_usage += memory_usage  # Add the memory usage of the chunk to the total

        # Gather data types and non-null counts
        for column in chunk.columns:
            column_dtype = chunk[column].dtype

            # Aggregate the information
            if column in info:
                info[column]['Data Types'].add(column_dtype)
                info[column]['Non-Null Count'] += chunk[column].count()
            else:
                info[column] = {'Data Types': {column_dtype}, 'Non-Null Count': chunk[column].count()}

# Create a DataFrame from the gathered information
info_df = pd.DataFrame(info).T.reset_index()
info_df.rename(columns={'index': 'Column Name'}, inplace=True)

# Print the aggregated info
print("Info for the Whole Data Frame:")
print(info_df)

# Print the total memory usage
print(f"Total Memory Usage: {total_memory_usage / (1024 * 1024):.2f} MB")  # Convert to MB for readability
# Out:
# Aggregated Info by Column Name for the Whole DataFrame:
#                   Column Name Data Types Non-Null Count
# 0                          id    {int32}        7027431
# 1                       title   {object}        7027431
# 2                     authors   {object}        1668716
# 3                 author_name   {object}        7027431
# 4                   author_id    {int32}        7027431
# 5                     work_id    {int32}        7027431
# 6                        isbn   {object}        7027431
# 7                      isbn13   {object}        7027431
# 8                        asin   {object}        7027431
# 9                    language   {object}        7027431
# 10             average_rating  {float16}        7027431
# 11                rating_dist   {object}        7027431
# 12              ratings_count    {int32}        7027431
# 13         text_reviews_count    {int32}        7027431
# 14           publication_date   {object}        7027431
# 15  original_publication_date   {object}        7027431
# 16                     format   {object}        7027431
# 17        edition_information   {object}        7027431
# 18                  image_url   {object}        7027431
# 19                  publisher   {object}        7027431
# 20                  num_pages   {object}        7027431
# 21                  series_id   {object}        7027431
# 22                series_name   {object}        7027431
# 23            series_position   {object}        7027431
# 24                    shelves   {object}        7027431
# 25                description   {object}        7027431
# Total Memory Usage: 16379.45 MB

# %%
import numpy as np
# Read the data in chunks
df_chunks = pd.read_json(filename1, lines=True, chunksize=chunk_size, dtype=dtype_mapping)

# Initialize variables to store statistics
t = []

missing = 0
empty = 0

# Process each chunk and gather statistics
for chunk in df_chunks:
    missing += chunk.isna().sum()
    empty += chunk[chunk == ''].count()

    t.append(chunk[['average_rating', 'ratings_count', 'text_reviews_count']])

#Create a dataframe with the columns of interest
df = pd.concat(t)

# Print the missing and empty data
print('Missing Data\n', missing)
print('\nEmpty Data\n', empty)

# Print the aggregated statistics
print("\nAggregated Statistics for Specific Columns")
print("\nMean:")
print(df.mean())
print("\nStandard Deviation:")
print(df.std())
print("\nQuantiles:")
print(df.quantile([0.25, 0.5, 0.75]))
print("\nMinimum")
print(df.min())
print("\nMaximum")
print(df.max())
# Out:
# Missing Data
#  id                                 0
# title                              0
# authors                      5358715
# author_name                        0
# author_id                          0
# work_id                            0
# isbn                               0
# isbn13                             0
# asin                               0
# language                           0
# average_rating                     0
# rating_dist                        0
# ratings_count                      0
# text_reviews_count                 0
# publication_date                   0
# original_publication_date          0
# format                             0
# edition_information                0
# image_url                          0
# publisher                          0
# num_pages                          0
# series_id                          0
# series_name                        0
# series_position                    0
# shelves                            0
# description                        0
# dtype: int64
#
# Empty Data
#  id                                 0
# title                             33
# authors                            0
# author_name                        0
# author_id                          0
# work_id                            0
# isbn                         2414175
# isbn13                       2012197
# asin                         5881045
# language                     4340264
# average_rating                     0
# rating_dist                        0
# ratings_count                      0
# text_reviews_count                 0
# publication_date             2138139
# original_publication_date     415746
# format                       2240100
# edition_information          6465533
# image_url                          0
# publisher                    2165557
# num_pages                    3071835
# series_id                    5162295
# series_name                  5162328
# series_position              5354166
# shelves                            0
# description                  1565403
# dtype: int64
#
# Aggregated Statistics for Specific Columns
#
# Mean:
# 6701.21388051057
#
# Standard Deviation:
# 93364.46392625541
#
# Quantiles:
#       average_rating  ratings_count  text_reviews_count
# 0.25        3.359375            3.0                 0.0
# 0.50        3.810547           45.0                 5.0
# 0.75        4.078125          771.0                64.0
# average_rating        0.0
# ratings_count         0.0
# text_reviews_count    0.0
# dtype: float64
# average_rating              5.0
# ratings_count         7400639.0
# text_reviews_count     174524.0
# dtype: float64

# %% [markdown]
# # RQ 2

# %% [markdown]
# ## Plot the number of books for each author in descending order.

# %%
# Read the data
df = pd.read_json(filename, lines=True, dtype=dtypes)

def update_gender(gender):
    for new_gender, mappings in category_mapping.items():
        if gender in mappings:
            return new_gender
    return 'Other'  # Assign to 'Other' if not found in any category

# Apply the custom function to update the genders
df['gender'] = df['gender'].apply(update_gender)

# Since in the authors there are also publishers and companies, filter the authors using gender
# Companies and publisher will have a gender that is not female, male or queer
df = df[df['gender'] != 'Other']

def count_unique_books(book_list):
    return len(set(book_list))

# Count the number of books for each author
df['book_count'] = df['book_ids'].apply(count_unique_books)

# Sort the DataFrame in descending order by book count
df = df.sort_values(by='book_count', ascending=False)

# Choose the top N authors since plotting all of them would result in a plot not very messy and not meaningful
N = 50
df_plot = df.head(N)

# Plot the number of books for each author
plt.figure(figsize=(10, 6))
plt.bar(df_plot['name'], df_plot['book_count'])
plt.xticks(rotation=90)
plt.xlabel('Author')
plt.ylabel('Number of Books')
plt.title('Number of Books by Author (Descending Order), Top {%s}' % N)

plt.show();

# %% [markdown]
# ## Which book has the highest number of reviews?

# %%
# Read the data in chunks
df_chunks = pd.read_json(filename1, lines=True, chunksize=chunk_size, dtype=dtype_mapping)

# Create a dictionary to store review counts for each book
review_counts = {}

aa = []

# Iterate through each chunk and update the review counts
for chunk in df_chunks:
    chunk = chunk[['title', 'text_reviews_count']]
    aa.append(chunk)
    # Since there are more editions for every book, but we are interested in the book with the most reviews, not the edition,
    # we group the books by title
    chunk = chunk.groupby('title')['text_reviews_count'].sum().reset_index()


    # Update the review counts in the dictionary
    for _, row in chunk.iterrows():
        book_title = row['title']
        review_count = row['text_reviews_count']
        review_counts[book_title] = review_counts.get(book_title, 0) + review_count
aa = pd.concat(aa)
print(aa.groupby('title')['text_reviews_count'].sum())

# Find the book with the highest number of reviews
max_reviews_book = max(review_counts, key=review_counts.get)
max_reviews_count = review_counts[max_reviews_book]

# %%
print(max_reviews_book, max_reviews_count)
# Out:
# Pride and Prejudice 85759005

# %%
# If instead we are interested in the edition of the book with most reviews

# Read the data in chunks
df_chunks = pd.read_json(filename1, lines=True, chunksize=chunk_size, dtype=dtype_mapping)

# Create a dictionary to store review counts for each book
l = []

# Iterate through each chunk and update the review counts
for chunk in df_chunks:
    chunk = chunk[['title', 'text_reviews_count']]
    l.append(chunk)

df = pd.concat(l)
print('Title', df.sort_values(by='text_reviews_count').iloc[-1][0])
print('reviews', df.sort_values(by='text_reviews_count').iloc[-1][1])
# Out:
# ＫＹＯＵＨＡＮ～共犯～ (二見シャレード文庫) (Japanese Edition) 174524

# %% [markdown]
# ## Which are the top ten and ten worst books concerning the average score?

# %%
# Read the data in chunks
df_chunks = pd.read_json(filename1, lines=True, chunksize=chunk_size, dtype=dtype_mapping)

# Create a dictionary to store average rating for each book
ratings = {}

# Iterate through each chunk and update the ratings
for chunk in df_chunks:
    chunk = chunk[['title', 'average_rating', 'ratings_count']]
    chunk.average_rating.apply(lambda x: x if x >= 0 else None)
    chunk.title.apply(lambda x: x if x != '' else None).dropna()
    chunk = chunk[chunk['ratings_count'] > 1]

    # Update the review counts in the dictionary
    for _, row in chunk.iterrows():
        if row['title'] in ratings:
          ratings[row['title']].append(row['average_rating'])
        else:
          ratings[row['title']] = [row['average_rating']]

for title, average_rating in ratings.items():
  ratings[title] = sum(average_rating)/len(average_rating)

sorted_d = sorted(ratings.items(), key=lambda x: x[1])
top_ten = sorted_d[:10]
worst_ten = sorted_d[-10:]

print(top_ten, worst_ten)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-bf98c7a4c2e5> in <cell line: 8>()
#      12
#      13     # Update the review counts in the dictionary
# ---> 14     for _, row in chunk.iterrows():
#      15         if row['title'] in ratings:
#      16           ratings[row['title']].append(row['average_rating'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in iterrows(self)
#    1409         klass = self._constructor_sliced
#    1410         for k, v in zip(self.index, self.values):
# -> 1411             s = klass(v, index=columns, name=k).__finalize__(self)
#    1412             yield k, s
#    1413
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     468                     data = data.copy()
#     469             else:
# --> 470                 data = sanitize_array(data, index, dtype, copy)
#     471
#     472                 manager = get_option("mode.data_manager")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure, allow_2d)
#     595         else:
#     596             # we will try to copy by-definition here
# --> 597             subarr = _try_cast(data, dtype, copy, raise_cast_failure)
#     598
#     599     elif isinstance(data, ABCExtensionArray):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/construction.py in _try_cast(arr, dtype, copy, raise_cast_failure)
#     771         # perf shortcut as this is the most common case
#     772         if is_ndarray:
# --> 773             arr = cast(np.ndarray, arr)
#     774             if arr.dtype != object:
#     775                 return sanitize_to_nanoseconds(arr, copy=copy)
#
# KeyboardInterrupt:

# %%
worst_ten = sorted_d[:10]
top_ten = sorted_d[-10:]

print('Top ten books', top_ten)
print('\nWorst ten books concerining average rating: ', worst_ten)
# Out:
# [('Die Bücher und die Leserwelt', 5.0), ('Participants in the Great Race_To Save Earth (The Mind Trips of SCAM #3)', 5.0), ('The Valley Of Fire: A Cullers War Adventure Issue #2', 5.0), ('Noticing the Noise (The Silence between the Noise Book 1)', 5.0), ("The Boston Debutante's Friend (The Debutante Series Book 2)", 5.0), ('The Hanging Bridge: A Short British Horror Story', 5.0), ('HARSH LIVES', 5.0), ('Karya Pena Dik A 2014', 5.0), ('How To Create Your Own Reality', 5.0), ('Seeking Paradise / Swinging in Paradise', 5.0)] [('A More Perfect Way', 0.0), ('Justitiemord: Fallet Keith Cederholm', 0.0), ('The Rain Falls Like Rain: Poems', 0.0), ("Riches in Real Estate: A Beginner's Guide to Group Investing", 0.0), ('J.K.Lasser Pro Real Estate Investment Trusts: New Strategies for Portfolio Management', 0.0), ('Juiced Official Strategy Guide', 0.0), ('The Platonism of Marsilio Ficino: A Study of His Phaedrus Commentary, Its Sources and Genesis', 0.0), ('The Nightingale Question: Five Poets from Saxony', 0.0), ('Instant Songwriting with the Piano', 0.0), ('Wild Life Conservation in Theory and Practice: Lectures Delivered Before the Forest School of Yale University, 1914', 0.0)]

# %% [markdown]
# ## Explore the different languages in the book’s dataset, providing a proper chart summarizing how these languages are distributed throughout our virtual library.

# %%
# Read the data in chunks
df_chunks = pd.read_json(filename1, lines=True, chunksize=chunk_size, dtype=dtype_mapping)

# Create a Series to store the language's count
languages = pd.Series([], dtype='object')

# Iterate through each chunk and update the languages
for chunk in df_chunks:
    chunk.dropna(subset=['language'], inplace=True)
    chunk = chunk.language.value_counts()
    languages = pd.concat([languages, chunk])

languages1 = languages.to_frame().reset_index()
result = languages1.groupby('index').sum()
result = result.reset_index()
result = result.rename(columns={'index':'lang', 0:'count'})

# %%
import matplotlib.pyplot as plt
res2 = result.sort_values(by='count', ascending=False)
res2 = res2.drop(0)
plt.figure(figsize=(12, 6))
plt.bar(res2['lang'][:50], res2['count'][:50])
plt.xlabel('Language')
plt.ylabel('Count')
plt.title('Distribution of Languages in the Virtual Library')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### NO

# %%
# Read the data in chunks
df_chunks = pd.read_json(filename1, lines=True, chunksize=200000)

# Create a dictionary to store language counts
language_counts = {}

# Iterate through each chunk and update the language counts
for chunk in df_chunks:
    chunk = chunk[['language']]

    # Update the language counts in the dictionary
    for _, row in chunk.iterrows():
        language = row['language']
        if pd.notna(language):
            language_counts[language] = language_counts.get(language, 0) + 1

# Convert the language counts dictionary to a DataFrame
language_df = pd.DataFrame(list(language_counts.items()), columns=['Language', 'Count'])
language_df1 = language_df.drop(1)

# %%
# Create a bar chart to visualize the distribution of languages
language_df2 = language_df1.sort_values(by='Count', ascending=False)
plt.figure(figsize=(12, 6))
plt.bar(language_df2['Language'][:40], language_df2['Count'][:40])
plt.xlabel('Language')
plt.ylabel('Count')
plt.title('Distribution of Languages in the Virtual Library')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## How many books have more than 250 pages?

# %%
# Read the data in chunks
df_chunks = pd.read_json(filename1, lines=True, chunksize=chunk_size, dtypes=dtype_mapping)

# Create a variable to store number of books with more than 250 reviews
b_250_count = 0

# Iterate through each chunk
for chunk in df_chunks:
    # subselect only the column that contains the number of pages
    chunk = chunk[['num_pages']]
    # clean the data and convert the datatype
    chunk = chunk[chunk['num_pages'] != '']
    chunk = chunk.dropna(subset=['num_pages'])
    chunk['num_pages'] = chunk['num_pages'].astype('uint32')
    # update the count
    b_250_count += chunk[chunk['num_pages'] > 250]['num_pages'].count()

print(b_250_count)
# Runtime 13 min
# Out:
# 1810335

# %% [markdown]
# ## Plot the distribution of the fans count for the 50 most prolific authors (the ones who have written more books).

# %%
# Read the data
df = pd.read_json(filename, lines=True, dtype=dtypes)
def count_unique_books(book_list):
    return len(set(book_list))

def update_gender(gender):
    for new_gender, mappings in category_mapping.items():
        if gender in mappings:
            return new_gender
    return 'Other'

# Apply the custom function to update the genders
df['gender'] = df['gender'].apply(update_gender)

# FIlter by gender to remove publishers and companies
df = df[df['gender'] != 'Other']
# Ensure fans count is > 0 and not Null
df['fans_count'] = df.fans_count.apply(lambda x: x if x > 0 else None)
df.dropna(subset=['fans_count'], inplace=True)

# Count the number of books for each author
df['book_count'] = df['book_ids'].apply(count_unique_books)

# Sort the DataFrame in descending order by book count
df = df.sort_values(by='book_count', ascending=False)

# One author seems an outlier so remove it
df_filtered = df[df['name'] != 'Stephen King']

# Create a dataframe with only the top 50 authors
top_50_authors = df_filtered['id'][:50]
df_top_50_authors = df_filtered[df_filtered['id'].isin(top_50_authors)]
# Out:
# <ipython-input-8-6654bc5d5baa>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fans_count'] = df.fans_count.apply(lambda x: x if x > 0 else None).dropna()

# %%
# Create a histogram to plot the distribution of fans count
plt.figure(figsize=(10, 6))
plt.hist(df_top_50_authors['fans_count'], bins=20, edgecolor='k', alpha=0.7, density=True)
plt.xlabel('Fans Count')
plt.title('Distribution of Fans Count for the 50 Most Prolific Authors')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#plt.figure(figsize=(10, 6))
#plt.boxplot([df_top_50_authors[df_top_50_authors['id'] == author]['fans_count'] for author in top_50_authors], labels=top_50_authors)
#plt.xlabel('Authors')
#plt.ylabel('Fans Count')
#plt.title('Distribution of Fans Count for the 50 Most Prolific Authors')
#plt.xticks(rotation=90)
#plt.grid(axis='y', linestyle='--', alpha=0.7)
#plt.show()

# %% [markdown]
# # RQ3

# %%
df_chunks = pd.read_json(filename1, lines=True, chunksize=100_000, dtype=dtype_mapping)

# Create an empty DataFrame to store the results
df_books = pd.DataFrame()
# Read the data in chunks
for chunk in df_chunks:
    chunk = chunk[['id', 'title', 'original_publication_date', 'num_pages', 'series_id',
                 'series_name', 'author_name', 'author_id', 'average_rating', 'format',
                 'rating_dist', 'ratings_count', 'text_reviews_count']]
    df_books = pd.concat([df_books, chunk], ignore_index=True)

# %% [markdown]
# ## Write a function that takes as input a year and returns as output the following information:
#
# The number of books published that year.
#
# The total number of pages written that year.
#
# The most prolific month of that year.
#
# The longest book written that year.

# %%
from datetime import datetime
from dateutil.parser import parse
#We create two different lists, date with the entire original publication date in tuples, and date_y with just the year.
#The problem is that for some books the month is missing.
#date_y=[]
#date_m=[]

#for i in df_books.original_publication_date:
#    date_y.append(i.split('-')[0])
##Some books don't have the specified month of publication date, but just the year.
##So we create a list for the months and when it is not specified we insert 0.
#    if len(i.split('-')) > 1:
#        date_m.append(i.split('-')[1])
#    else:
#        date_m.append(0)

date_format = '%Y-%m-%d'
# Convert the date strings to a consistent date format
df_books['original_publication_date'] = pd.to_datetime(df_books['original_publication_date'], format=date_format, errors='coerce')
# Convert 'original_publication_date' column to datetime using dateutil
#df_books = df_books[df_books['original_publication_date'].apply(lambda x: int(x.split('-')[0]) < 2025 if pd.notna(x) else True)]
#df_books['original_publication_date'] = df_books['original_publication_date'].apply(lambda x: parse(x, default=datetime(2025, 1, 1), ignoretz=True) if x else x)


def date_y(date):
    if pd.notna(date):
        return int(date.year)
    else:
        return 0

def date_m(date):
    if pd.notna(date):
        return int(date.month)
    else:
        return 0


df_books['publication_year'] = df_books.original_publication_date.apply(date_y)
df_books['publication_month'] = df_books.original_publication_date.apply(date_m)

#date_y = [int(i) for i in date_y]
#date_y = ['0' if i=='' else i for i in date_y]
#date_m = [int(i) for i in date_m]
##We add the column with the years and the months
#df_books['publication_year'] = date_y
#df_books['publication_month'] = date_m
df_books['num_pages'] = df_books['num_pages'].replace('', '0')
df_books['num_pages'] = df_books['num_pages'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-55f42c658f00> in <cell line: 33>()
#      31 #df_books['original_publication_date'] = pd.to_datetime(df_books['original_publication_date'], format=date_format, errors='coerce')
#      32 # Convert 'original_publication_date' column to datetime using dateutil
# ---> 33 df_books = df_books[df_books['original_publication_date'].apply(lambda x: int(x.split('-')[0]) < 2025 if pd.notna(x) else True)]
#      34 df_books['original_publication_date'] = df_books['original_publication_date'].apply(lambda x: parse(x, default=datetime(2025, 1, 1), ignoretz=True) if x else x)
#      35
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4769         dtype: float64
#    4770         """
# -> 4771         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4772
#    4773     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1121
#    1122         # self.f is Callable
# -> 1123         return self.apply_standard()
#    1124
#    1125     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1172             else:
#    1173                 values = obj.astype(object)._values
# -> 1174                 mapped = lib.map_infer(
#    1175                     values,
#    1176                     f,
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-5-55f42c658f00> in <lambda>(x)
#      31 #df_books['original_publication_date'] = pd.to_datetime(df_books['original_publication_date'], format=date_format, errors='coerce')
#      32 # Convert 'original_publication_date' column to datetime using dateutil
# ---> 33 df_books = df_books[df_books['original_publication_date'].apply(lambda x: int(x.split('-')[0]) < 2025 if pd.notna(x) else True)]
#      34 df_books['original_publication_date'] = df_books['original_publication_date'].apply(lambda x: parse(x, default=datetime(2025, 1, 1), ignoretz=True) if x else x)
#      35
#
# ValueError: invalid literal for int() with base 10: ''

# %%
df_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6611685 entries, 0 to 7027430
# Data columns (total 16 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   id                         int32
#  1   title                      object
#  2   original_publication_date  object
#  3   num_pages                  int64
#  4   series_id                  object
#  5   series_name                object
#  6   author_name                object
#  7   author_id                  int32
#  8   average_rating             float16
#  9   format                     object
#  10  rating_dist                object
#  11  ratings_count              int32
#  12  text_reviews_count         int32
#  13  parsed_dates               object
#  14  publication_year           int64
#  15  publication_month          int64
# dtypes: float16(1), int32(4), int64(3), object(8)
# memory usage: 718.8+ MB

# %%
df_books[df_books.title == 'Cancioneiro da Ajuda - volume 1']
# Out:
#                id                            title original_publication_date  \
# 2573381  10271670  Cancioneiro da Ajuda - volume 1                     05-25
#
#          num_pages series_id series_name                        author_name  \
# 2573381        994                        Carolina Michaëlis de Vasconcelos
#
#          author_id  average_rating     format                  rating_dist  \
# 2573381   14760776             5.0  Hardcover  5:1|4:0|3:0|2:0|1:0|total:1
#
#          ratings_count  text_reviews_count parsed_dates  publication_year  \
# 2573381              1                   0         None                 0
#
#          publication_month
# 2573381                  0

# %%
filter = (df_books['publication_year'] > 0) & (df_books['publication_year'] < 2024)
df_books_filtered_y = df_books[filter]

# %%
print(len(df_books))
print(len(df_books_filtered_y))
# Out:
# 6611685
# 4292657

# %%
import pandas as pd
from datetime import datetime

# Sample DataFrame with 'original_publication_date' column
data = {'original_publication_date': ['2023-10-15', '2022-11', '01-05', '2021', '1500', None]}
d = pd.DataFrame(data)

# Define functions to extract year and month from datetime
def date_y(date):
    if pd.notna(date):
        return date.year
    else:
        return 0

def date_m(date):
    if pd.notna(date):
        return date.month
    else:
        return 0

# Convert 'original_publication_date' column to datetime
d['original_publication_date'] = pd.to_datetime(d['original_publication_date'], format='%Y-%m-%d', errors='coerce')

# Extract year and month using the functions
d['publication_year'] = d['original_publication_date'].apply(date_y)
d['publication_month'] = d['original_publication_date'].apply(date_m)

print(d)
# Out:
#   original_publication_date  publication_year  publication_month
# 0                2023-10-15              2023                 10
# 1                2022-11-01              2022                 11
# 2                       NaT                 0                  0
# 3                2021-01-01              2021                  1
# 4                       NaT                 0                  0
# 5                       NaT                 0                  0

# %%
import pandas as pd
from datetime import datetime
from dateutil.parser import parse

# Sample DataFrame with 'original_publication_date' column
data = {'original_publication_date': ['2023-10-15', '2022-11', '01-05', '2021', '100', None]}
d = pd.DataFrame(data)

# Define functions to extract year and month from datetime
def date_y(date):
    if date:
        return date.year
    else:
        return 0

def date_m(date):
    if date:
        return date.month
    else:
        return 0

# Convert 'original_publication_date' column to datetime using dateutil
d['original_publication_date'] = d['original_publication_date'].apply(lambda x: parse(x, default=datetime(2025, 1, 1), ignoretz=True) if x else x)

# Extract year and month using the functions
d['publication_year'] = d['original_publication_date'].apply(date_y)
d['publication_month'] = d['original_publication_date'].apply(date_m)

print(d)
# Out:
#   original_publication_date  publication_year  publication_month
# 0       2023-10-15 00:00:00              2023                 10
# 1       2022-11-01 00:00:00              2022                 11
# 2       2025-01-05 00:00:00              2025                  1
# 3       2021-01-01 00:00:00              2021                  1
# 4       0100-01-01 00:00:00               100                  1
# 5                      None                 0                  0

# %%
from statistics import mode
def info_year(year):
    books = df_books[df_books['publication_year'] == year]

    #The number of books published that year:
    published_b = len(books.index)

    #The total number of pages written that year:
    #books['num_pages']= books['num_pages'].replace('', '0')
    #books['num_pages']= books['num_pages'].astype(int)
    num_pages = books['num_pages'].sum()

    #The most prolific month of that year:
    months = books['publication_month']
    months_small = []
    for i in months: #Eliminating the 0 that are the unspecified months
        if i != 0 and i < 13:
            months_small.append(i)
    if months_small:
        frequent_month = mode(months_small)
    else: #In the case this list is empty, it means that the months were all 0 (not specified)
        frequent_month = "There isn't enough information to find the most prolific month of this year"

    #The longest book written that year:
    index_max = books['num_pages'].idxmax() #Estracting the index of the maximum
    longest_b = books.loc[index_max, 'title']


    return(published_b, num_pages, frequent_month, longest_b)

# %% [markdown]
# ## Use this function to build your data frame: the primary key will be a year, and the required information will be the attributes within the row. Finally, show the head and the tail of this new data frame considering the first ten years registered and the last ten years.

# %%
years = df_books_filtered_y['publication_year'].unique() #years is the primary key
list_years = [[i] + list(info_year(i)) for i in years]

df_years = pd.DataFrame(list_years, columns = ['years', 'published_books', 'tot_num_pages', 'most_frequent_month', 'longest_book'])
df_years.sort_values(by='years', inplace=True)
print('First ten years registered:')
print(df_years.head(10))
print('\nLast ten years registered:')
print(df_years.tail(10))
# Out:
# First ten years registered:
#      years  published_books  tot_num_pages  most_frequent_month  \
# 237   1678              946         120058                    2
# 325   1679               31           2332                    1
# 279   1680               84          13352                    1
# 197   1681              120          12774                    1
# 257   1682              395          41882                    1
# 320   1683               47           5402                    1
# 256   1684               99           9193                    1
# 305   1685               79           9262                    1
# 307   1686              100          12250                    1
# 311   1687              165          34329                    1
#
#                                           longest_book
# 237                            Pilgrim's Progress, The
# 325  Strange Stories from a Chinese Studio, Vol. 1 ...
# 279  Discourses on Government. to Which Is Added, a...
# 197  The Buccaneers of America: A True Account of t...
# 257                                           Komödien
# 320  The Glory of Christ (Works of John Owen, Volum...
# 256     Love-Letters Between a Nobleman and His Sister
# 305  Seneca's Morals by Way of Abstract, of Benefit...
# 307                                    The Major Works
# 311  The Principia: Mathematical Principles of Natu...
#
# Last ten years registered:
#      years  published_books  tot_num_pages  most_frequent_month  \
# 100   2014           358321       44582397                    1
# 159   2015           119958       14382833                    1
# 245   2016             3433         737917                    1
# 277   2017             1024         178156                    1
# 293   2018              411          82068                    1
# 238   2019              305          49524                    1
# 188   2020              260          35080                    5
# 343   2021               38           8520                    1
# 344   2022               18           1280                   10
# 345   2023                5            463                    1
#
#                                           longest_book
# 100   A Most Unlikely Countess (To Love a Wildcat, #2)
# 159  Revel for the American Nation: A History of th...
# 245                                          Homestuck
# 277                             The Starfarers Quartet
# 293                                              地海六部曲
# 238                                      Nouvelles Les
# 188          The Complete Ripley Novels (Ripley, #1-5)
# 343  The Navigator's Children (The Last King of Ost...
# 344  Highland Ever After (The Montgomerys and Armst...
# 345                                         Apocalypse

# %% [markdown]
# # RQ4

# %%
df = pd.read_json(filename, lines=True, dtype=dtypes)

# %% [markdown]
# ## You should be sure there are no eponymous (different authors who have precisely the same name) in the author's dataset. Is it true?

# %%
duplicates = df.name[df['name'].duplicated(keep=False)]
print(duplicates)
if len(duplicates) == 0:
  print("It's true, there are no eponymous authors")
else:
  print("It's not true, there are eponymous authors")
# Out:
# 8639            Peter  Marshall
# 14943      Christopher Phillips
# 19037     William Messner-Loebs
# 74780           Peter  Marshall
# 99922             Yordan Yovkov
# 134763                محمد نجيب
# 165580      Jackson Butch Guice
# 171064                محمد نجيب
# 178267             Q. Hayashida
# 185467            Dimitar Dimov
# 193531      Jackson Butch Guice
# 194321             Q. Hayashida
# 200003     Christopher Phillips
# 228145            Yordan Yovkov
# 270233        James C.L. Carson
# 311093    William Messner-Loebs
# 314855            Dimitar Dimov
# 315853        James C.L. Carson
# Name: name, dtype: string
# It's not true, there are eponymous authors

# %% [markdown]
# ## Write a function that, given a list of author_id, outputs a dictionary where each author_id is a key, and the related value is a list with the names of all the books the author has written.

# %%
def books_dict(author_ids, dataframe):
  diz = dict()
  for i in author_ids:
    author_books = dataframe[dataframe['author_id'] == int(i)]
    titles = list(author_books['title'])
    diz[i] = titles

  return(diz)

# %%
df_books[df_books.author_id == 16777164]
# Out:
# Empty DataFrame
# Columns: [id, title, original_publication_date, num_pages, series_id, series_name, author_name, author_id, average_rating, format, rating_dist, ratings_count, text_reviews_count, publication_year, publication_month]
# Index: []

# %% [markdown]
# ## What is the longest book title among the books of the top 20 authors regarding their average rating? Is it the longest book title overall?

# %%
authors_total = df[['average_rating', 'id','name', 'ratings_count']]
authors_total = authors_total.sort_values(by='average_rating', ascending=False)
authors_total = authors_total[authors_total.ratings_count > 2]
authors_20top = authors_total[:20] #Find the top 20 authors
diz_20top = books_dict(authors_20top['id'], df_books)

max_t = 0
for id, titles in diz_20top.items():
  for i in titles:
    if len(i) > max_t:
        max_t = len(i)
        longest_book = i
print("\nThe longest book title among the books of the top 20 authors regarding their average rating is:\n", longest_book)
# Out:
# The longest book title among the books of the top 20 authors regarding their average rating is:
#  History of the postage stamps of the United States of America

# %%
print(authors_20top)
# Out:
#         average_rating        id                      name  ratings_count
# 180568             5.0  20890814            HARSHIT PORWAL              3
# 180620             5.0   4444870         John Kerr Tiffany              4
# 180607             5.0   4444483                Tux Toledo              5
# 303354             5.0  13537047  Elizabeth Roberts-Zibbel              5
# 303366             5.0  13538021             Jenna Cornell             14
# 180709             5.0   4447710           Daniel LaFavers              4
# 180417             5.0   4435832          Stephen Emmerson              3
# 303276             5.0  13531911                Susan Baer              4
# 181055             5.0  17559128                     San J              3
# 180897             5.0   4453151           John Poindexter              8
# 303293             5.0  13533083           Սեյրան Քամալյան              3
# 303294             5.0  13533102          Ervinell Walters              4
# 179810             5.0  20884789              Elle Carling              5
# 180346             5.0   4432081               Amy Caudill              3
# 303574             5.0  13550588           Sabrina Steward              3
# 303577             5.0  13550642           Matt Strawbrich              4
# 303580             5.0  13550911               Terence Daw              3
# 303583             5.0  13551238            Ivan  Marković              4
# 179983             5.0  20885684                John Espie              7
# 180024             5.0   4418944         Dennis R. Gilmour              3

# %%
print(diz_20top)
# Out:
# {'20890814': [], '17556718': ['Readings in child development', 'Human Quality Control; The Breeding And Feeding Of Genius', 'Principles Of Abnormal Psychology', 'Fundamentals Of Child Development', 'Readings in Child Development', 'Fundamentals of child development'], '21222299': [], '4444870': ['History of the postage stamps of the United States of America', 'History of the Postage Stamps of the United States of America', 'History of the Postage Stamps of the United States of America', 'History of the Postage Stamps of the United States', 'The Philatelical Library'], '4444483': ['The Lovable Rogue Mysteries', 'The Lovable Rogue Mysteries'], '13537047': ['The Migraine Diaries #1: Diagnosis [1981]'], '13538021': ['Fantastic Illusions of Life, Love, the Birds, and the Bees'], '4447710': ['Broken Mirror', "Carpenter's Mark", "Carpenter's Mark"], '17015962': [], '4435832': ['Attack Of The Gas Powered Angels'], '4446700': ['Sara Rose, Kid Lawyer'], '13531911': ["Conceit: It's All About Jake (The Lincoln Series, Prequel)"], '17559128': [], '4453151': ['All in the Family Cruise', 'All in the Family Cruise', 'She Rises at Dawn', "Dreamer's Paradise", 'Hollywood Dream', 'All in the Family Cruise', 'Hollywood Dream'], '13533083': ["Hoghe Tak'anum E Matnerits': Vipak", 'Ավոն մեր աչքերով'], '13533102': ['Afterwards'], '4454479': ["A Winter's Tale", "A Winter's Tale"], '13533830': ['The Lightbridge Mystery'], '4434010': ["What's Your Motivation?: Identifying and Understanding What Drives You", "What's Your Motivation?: Values Matter"], '20885296': []}

# %%
df_books[df_books.title == 'Political Debates Between Hon. Abraham Lincoln and Hon. Stephen A. Douglas, in the Celebrated Campaign of 1858 in Illinois; Including the Preceding Speeches of Each, at Chicago, Springfield, Etc.; Also the Two Great Speeches of Mr. Lincoln in Ohio, in 185']
# Out:
#               id                                              title  \
# 2452831  9821190  Political Debates Between Hon. Abraham Lincoln...
#
#         original_publication_date  num_pages series_id series_name  \
# 2452831                1899-01-01        290
#
#              author_name  author_id  average_rating     format  \
# 2452831  Abraham Lincoln        229        4.160156  Paperback
#
#                                  rating_dist  ratings_count  \
# 2452831  5:109|4:106|3:38|2:11|1:2|total:266            266
#
#          text_reviews_count  publication_year  publication_month
# 2452831                  47              1899                  1

# %%
df[df.id == '229']
# Out:
#      ratings_count  average_rating  text_reviews_count  \
# 100          15558        4.351562                 795
#
#                                               work_ids  \
# 100  [4694, 21740, 21738, 17397442, 1200856, 138402...
#
#                                               book_ids  works_count   id  \
# 100  [397, 20549, 20547, 753796, 8454621, 143469, 7...          729  229
#
#                 name gender  \
# 100  Abraham Lincoln   male
#
#                                              image_url  \
# 100  https://images.gr-assets.com/authors/119851815...
#
#                                                  about  fans_count
# 100  Abraham Lincoln was the sixteenth President of...        1405

# %%
df[df.id == '20885296']
# Out:
#         ratings_count  average_rating  text_reviews_count    work_ids  \
# 179915              2             5.0                   1  [87157134]
#
#           book_ids  works_count        id        name gender  \
# 179915  [55943682]            1  20885296  Kori Nemme
#
#                                                 image_url  \
# 179915  https://images.gr-assets.com/authors/160585911...
#
#                                                     about  fans_count
# 179915  Kori Nemme is an author, educator and curiosit...           1

# %%
longest_all_idx = df_books['title'].apply(len).idxmax()

# Retrieve the title with the maximum length
longest_all = df_books.loc[longest_all_idx, 'title']

if longest_all == longest_book:
    print('It is')
else:
    print('It is not')
# Out:
# It is not

# %% [markdown]
# ## What is the shortest overall book title in the dataset? If you find something strange, provide a comment on what happened and an alternative answer.

# %%
shortest_all_idx = df_books['title'].apply(len).idxmin()
# Retrieve the title with the maximum length
shortest_all = df_books.loc[shortest_all_idx, 'title']
print(shortest_all)

# Alternative answer: remove books with empty title
df_bt = df_books[df_books.title != '']
shortest_all_idx = df_bt['title'].apply(len).idxmin()
# Retrieve the title with the maximum length
shortest_all = df_bt.loc[shortest_all_idx, 'title']
print(shortest_all)
# Out:
# a

# %% [markdown]
# # RQ5

# %% [markdown]
# ## We can consider the authors with the most fans to be influential. Let’s have a deeper look. Plot the top 10 most influential authors regarding their fan count and number of books. Who is the most influential author?

# %%
df['books_count'] = df['book_ids'].apply(len)

# %%
#Ordering by fan count
authors_influential = df.sort_values(by = 'fans_count', ascending = False)
authors_influential = authors_influential[:10] #uno per fans ed uno per book o doppio sort
#Ordering by number of books
authors_influential['books_count'] = authors_influential['book_ids'].apply(len)
authors_influential = authors_influential.sort_values(by = 'books_count', ascending = False)
print("The top 10 most influential authors are:\n", authors_influential['name'])

most_influent = authors_influential.iloc[0]
print("The most influential author is: ", most_influent['name'])
# Out:
# The top 10 most influential authors are:
#  1017             Stephen King
# 1161          James Patterson
# 27110         Cassandra Clare
# 4537             Rick Riordan
# 169374          Veronica Roth
# 205870         Colleen Hoover
# 100166             John Green
# 3818      Neil deGrasse Tyson
# 32358            Mindy Kaling
# 6397              Bill  Gates
# Name: name, dtype: string
# The most influential author is:  Stephen King

# %%
# Plot the data
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
fig.suptitle("Top 10 Influential Authors")

# Plot fan count
ax[0].barh(authors_influential['name'], authors_influential['fans_count'])
ax[0].set_xlabel('Fans Count')
ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation=45);


# Plot number of books
ax[1].barh(authors_influential['name'], authors_influential['books_count'], color='orange')
ax[1].set_xlabel('Books Count')
ax[1].set_xticklabels(ax[1].get_xticklabels(), rotation=45);

plt.show()
# Out:
# <ipython-input-34-2c166b170927>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation=45)
# <ipython-input-34-2c166b170927>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[1].set_xticklabels(ax[1].get_xticklabels(), rotation=45)

# %% [markdown]
# ## Have they published any series of books? If any, extract the longest series name among these authors.

# %%
names_influent = authors_influential['name']
for i in names_influent:
    influent = df_books[df_books['author_name'] == i]
print(influent) #errore no save
# Out:
# Stephen King
# James Patterson
# Cassandra Clare
# Rick Riordan
# Veronica Roth
# Colleen Hoover
# John Green
# Neil deGrasse Tyson
# Mindy Kaling
# Bill  Gates
#                id                                              title  \
# 26016       41609  Business @ the Speed of Thought : Using a Digi...
# 26017       41617  Business @ The Speed Of Thought: Succeeding In...
# 26018       41619  Business @ the Speed of Thought: Succeeding in...
# 26019       41623                              The Road Ahead CD-ROM
# 26021       41633         Bill Gates: los negocios en la era digital
# ...           ...                                                ...
# 6719134  24560943  Üzlet @ gondolat sebességével: Működik a digit...
# 6912434  25217967                   Business at the Speed of Thought
# 6944696  25301776                    The Road Ahead: Book and Cd-Rom
# 6976713  25388551                Negócios @ Velocidade do Pensamento
# 6978746  25393898                                Ceļš ved uz priekšu
#
#         original_publication_date num_pages series_id series_name  \
# 26016                  1999-03-01
# 26017                  1999-03-01       527
# 26018                  1999-03-01       496
# 26019                  1995-11-21
# 26021                  1999-03-01       528
# ...                           ...       ...       ...         ...
# 6719134                1999-03-01       472
# 6912434                1999-03-01
# 6944696                1995-11-21
# 6976713                1999-03-01       398
# 6978746                1995-11-21       408
#
#          author_name  author_id  average_rating     format  \
# 26016    Bill  Gates      23470        3.830078
# 26017    Bill  Gates      23470        3.830078  Paperback
# 26018    Bill  Gates      23470        3.830078  Paperback
# 26019    Bill  Gates      23470        3.740234   Audio CD
# 26021    Bill  Gates      23470        3.830078  Paperback
# ...              ...        ...             ...        ...
# 6719134  Bill  Gates      23470        3.830078  Hardcover
# 6912434  Bill  Gates      23470        3.830078
# 6944696  Bill  Gates      23470        3.740234
# 6976713  Bill  Gates      23470        3.830078  Hardcover
# 6978746  Bill  Gates      23470        3.740234  Paperback
#
#                                          rating_dist  ratings_count  \
# 26016     5:1300|4:1148|3:948|2:296|1:138|total:3830           3830
# 26017     5:1300|4:1148|3:948|2:296|1:138|total:3830           3830
# 26018     5:1300|4:1148|3:948|2:296|1:138|total:3830           3830
# 26019    5:1092|4:1141|3:1083|2:349|1:101|total:3766           3766
# 26021     5:1300|4:1148|3:948|2:296|1:138|total:3830           3830
# ...                                              ...            ...
# 6719134   5:1303|4:1153|3:950|2:297|1:139|total:3842           3842
# 6912434   5:1300|4:1149|3:948|2:296|1:139|total:3832           3832
# 6944696  5:1093|4:1149|3:1086|2:351|1:101|total:3780           3780
# 6976713   5:1303|4:1154|3:950|2:297|1:139|total:3843           3843
# 6978746  5:1093|4:1149|3:1086|2:351|1:101|total:3780           3780
#
#          text_reviews_count
# 26016                   129
# 26017                   129
# 26018                   129
# 26019                   202
# 26021                   129
# ...                     ...
# 6719134                 132
# 6912434                 129
# 6944696                 205
# 6976713                 132
# 6978746                 205
#
# [88 rows x 13 columns]

# %%
names_influent = authors_influential['name']
influent = df_books[df_books['author_name'].isin(names_influent)]
# Out:
#                id                                              title  \
# 3114         4978           Wolves of the Calla (The Dark Tower, #5)
# 3178         5091                The Dark Tower (The Dark Tower, #7)
# 3179         5092                               Dark Tower Boxed Set
# 3180         5093              Song of Susannah (The Dark Tower, #6)
# 3181         5094      The Drawing of the Three (The Dark Tower, #2)
# ...           ...                                                ...
# 7025403  25515472               Lovci pokladů (Treasure Hunters, #1)
# 7025474  25515684                                            Shining
# 7025621  25516114              Athenas tecken (Olympens hjältar, #3)
# 7026344  25518086  The Lost Herondale (Tales from the Shadowhunte...
# 7026879  25519503                        Falsche Schuld (Private #4)
#
#         original_publication_date num_pages series_id  \
# 3114                   2003-11-04       931     40750
# 3178                   2004-09-21      1050     40750
# 3179                         2002               40750
# 3180                   2004-06-08       544     40750
# 3181                      1987-05       463     40750
# ...                           ...       ...       ...
# 7025403                2013-09-16       468    112891
# 7025474                1977-01-28       494    117014
# 7025621                2012-10-02       557     51379
# 7026344                2015-03-17         2    129925
# 7026879                2011-06-09              132156
#
#                                  series_name      author_name  author_id  \
# 3114                          The Dark Tower     Stephen King       3389
# 3178                          The Dark Tower     Stephen King       3389
# 3179                          The Dark Tower     Stephen King       3389
# 3180                          The Dark Tower     Stephen King       3389
# 3181                          The Dark Tower     Stephen King       3389
# ...                                      ...              ...        ...
# 7025403                     Treasure Hunters  James Patterson       3780
# 7025474                          The Shining     Stephen King       3389
# 7025621                The Heroes of Olympus     Rick Riordan      15872
# 7026344  Tales from the Shadowhunter Academy  Cassandra Clare     150038
# 7026879                              Private  James Patterson       3780
#
#          average_rating                 format  \
# 3114           4.160156  Mass Market Paperback
# 3178           4.238281              Paperback
# 3179           4.500000              Paperback
# 3180           3.970703  Mass Market Paperback
# 3181           4.210938              Paperback
# ...                 ...                    ...
# 7025403        4.171875              Hardcover
# 7025474        4.230469              Paperback
# 7025621        4.449219              Paperback
# 7026344        4.128906               Audio CD
# 7026879        3.789062
#
#                                                rating_dist  ratings_count  \
# 3114     5:70924|4:59040|3:25231|2:5798|1:2468|total:16...         163461
# 3178     5:78068|4:46242|3:19538|2:6044|1:3220|total:15...         153112
# 3179             5:3349|4:1087|3:426|2:104|1:67|total:5033           5033
# 3180     5:48753|4:50718|3:30170|2:7498|1:2635|total:13...         139774
# 3181     5:99563|4:84221|3:31953|2:6650|1:2446|total:22...         224833
# ...                                                    ...            ...
# 7025403          5:2742|4:1736|3:987|2:260|1:80|total:5805           5805
# 7025474  5:561861|4:373437|3:154259|2:35964|1:23084|tot...        1148605
# 7025621  5:275629|4:120816|3:41225|2:8225|1:5640|total:...         451535
# 7026344        5:6471|4:6281|3:3111|2:452|1:89|total:16404          16404
# 7026879      5:4232|4:6188|3:4704|2:1133|1:258|total:16515          16515
#
#          text_reviews_count
# 3114                   4395
# 3178                   5913
# 3179                     98
# 3180                   3893
# 3181                   8031
# ...                     ...
# 7025403                 739
# 7025474               25559
# 7025621               16929
# 7026344                1438
# 7026879                1030
#
# [16471 rows x 13 columns]

# %%
max = 0
longest_series_name = None #in the case there isn't a serie name
names_series = influent['series_name']
for j in names_series:
  if len(j) > max:
    max = len(j)
    longest_series_name = j

if longest_series_name != None:
  print("\nThe longest series name is: ", longest_series_name)
else:
  print("\nThere isn't a longest serie name.")
# Out:
# The longest series name is:  Percy Jackson and the Olympians: The Graphic Novels

# %%
s_max = influent.series_name.apply(len).idxmax()
longest = influent.loc[s_max, 'series_name']
if len(longest) > 0:
    print("The longest series name is: ", longest)
else:
  print("There isn't a longest serie name.")
# Out:
# The longest series name is:  Percy Jackson and the Olympians: The Graphic Novels

# %% [markdown]
# ## How many of these authors have been published in different formats? Provide a meaningful chart on the distribution of the formats and comment on it.

# %%
#First we create a dictionary with the author name as the key and the formats as the elements for each one.
def format_dict(author_name, dataframe):
  diz = dict()
  influent_10 = dataframe[dataframe['author_name']==author_name]
  formats= list(influent_10['format'])
  diz[author_name]=formats

  return(diz)

formats_count = {}
for i in names_influent:
    diz_format = format_dict(i, df_books)

    #Calculating the number of unique formats for the author i
    formats_set = set(diz_format[i])
    formats_count[i] = len(formats_set)

#Then we see if there are duplicates in the format.
count=0
for i in diz_format.values():
  if len(set(i)) != len(i):
    count = count+1
if count==0:
  print("\nThere are no author with different formats publications.\n")
if count==1:
  print("\nThere is ", count, " author with different formats publications.\n")
else:
  print("\nThere are ", count, " author with different formats publications.\n")

#Histogram
#All the formats in a list
formats_all = [i for j in diz_format.values() for i in j]
#Creating a dictionary that connets the formats to their index
unique_form = np.unique(formats_all)
diz_form_index = {} #creating a dictionary with all the formats and the corrispondent index
for index, format in enumerate(unique_form):
  diz_form_index[format]=index
#Converting the formats in numeric indexes
formats_numbers = [diz_form_index[i] for i in formats_all]
#Calculating the histogram
hist, bin_edges = np.histogram(formats_numbers, bins=np.arange(len(unique_form)+1))
#Bar chart
plt.bar(unique_form, hist, color='red')
plt.xlabel('Formats')
plt.ylabel('Number of books')
plt.title("Distribution of the book's formats")
plt.xticks(rotation=45, ha='right')  #Ruotating every name of the bars of 45° and putting them to the right
plt.tight_layout() #To be sure that the labels are not overlap
plt.show()
#From the histogram about the distribution of the formats we can see that the
#first format represented don't have a label. This is due to the fact that a
#lot of these books (more than 35 books of the influent authors) don't have this
#information specified in the data.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-58d7fa3bcef8> in <cell line: 11>()
#      10 formats_count = {}
#      11 for i in names_influent:
# ---> 12     diz_format = format_dict(i, df1)
#      13
#      14     #Calculating the number of unique formats for the author i
#
# NameError: name 'df1' is not defined

# %%
a_formats = influent.groupby(['author_name']).format.value_counts()
af = a_formats.to_frame()
for i in influent['author_name'].unique():
    print('\n', i, '\n', af.loc[i])
# Out:
#  Stephen King
#                                               format
# format
# Paperback                                      2841
# Hardcover                                      1437
#                                                1175
# Mass Market Paperback                           510
# ebook                                           344
# Audiobook                                       198
# Audio CD                                        193
# Kindle Edition                                  104
# Audio Cassette                                   82
# Audible Audio                                    57
# Library Binding                                  47
# Audio                                            39
# MP3 CD                                           18
# Preloaded Digital Audio Player                   13
# Unknown Binding                                  10
# Leather Bound                                     9
# School &amp; Library Binding                      5
# Paperback with flaps                              4
# MP3 Book                                          3
# Turtleback                                        3
# Paperback &amp; Audio CD                          2
# Pocket                                            2
# Tapa blanda                                       2
# paper                                             2
# 17 x 26                                           1
# Audible.com                                       1
# Audio Playaway                                    1
# Beterback                                         1
# Bolsillo                                          1
# Boxed Set                                         1
# CD-ROM                                            1
# Capa Mole                                         1
# Dwarsligger                                       1
# Econo-clad                                        1
# Fine Binding                                      1
# Flipback                                          1
# Hard Cover (gebonden)                             1
# Kindle                                            1
# Large Print                                       1
# Loose Leaf                                        1
# MP3                                               1
# MP3 on CD                                         1
# Microsoft Reader Edition                          1
# Pamphlet                                          1
# Paperback and CD                                  1
# Preloaded Digital Audio Player with earbuds       1
# Rústica bolsillo                                  1
# Slipcased Hardcover                               1
# Unbound                                           1
# Videocassette                                     1
# audiobook                                         1
# paperback                                         1
# جيبي                                              1
#
#  James Patterson
#                            format
# format
# Paperback                   1440
#                             1338
# ebook                        869
# Hardcover                    794
# Audio CD                     514
# Audiobook                    318
# Audio                        142
# Mass Market Paperback         77
# Kindle Edition                41
# Unknown Binding               41
# Audible Audio                 24
# MP3 CD                        10
# Audio Cassette                 7
# Library Binding                7
# large print                    5
# Large Print                    4
# Trade Paperback                2
# hardcover                      2
# Audible MP3 Download           1
# Audio Book                     1
# Broché                         1
# Capa mole                      1
# Dwarsligger                    1
# Electronic Book                1
# MP3                            1
# Playaway Audiobook             1
# Poche                          1
# Preloaded Digital Player       1
# Soft Cover                     1
# [large print] /                1
# audio                          1
# book                           1
# paperback                      1
#
#  Neil deGrasse Tyson
#                   format
# format
# Paperback            24
#                      14
# Hardcover            14
# ebook                11
# Audiobook             7
# Audio CD              6
# Audible Audio         2
# Kindle Edition        2
# Audio                 1
# Audio Cassette        1
# Library Binding       1
# MP3 CD                1
#
#  Rick Riordan
#                                  format
# format
# Paperback                          379
# Hardcover                          281
#                                    237
# Audio CD                            73
# ebook                               73
# Audiobook                           43
# Kindle Edition                      28
# Audible Audio                       11
# Library Binding                     10
# Mass Market Paperback               10
# Audio                                5
# Preloaded Digital Audio Player       5
# Broché                               2
# DVD                                  2
# MP3 Book                             2
# Board Book                           1
# Playaway                             1
# Trade Paperback                      1
# Unknown Binding                      1
#
#  Bill  Gates
#                         format
# format
#                            37
# Paperback                  20
# Hardcover                  15
# Audiobook                   5
# ebook                       5
# Audio CD                    3
# Mass Market Paperback       2
# Audio                       1
#
#  John Green
#                         format
# format
# Paperback                 244
# Hardcover                 100
#                            92
# ebook                      64
# Audio CD                   46
# Audiobook                  16
# Kindle Edition             16
# Audible Audio               5
# Library Binding             4
# Mass Market Paperback       3
# Flexcover                   2
# MP3 CD                      2
# Broché                      1
# Dwarsligger                 1
# Nook                        1
# Poche                       1
#
#  Cassandra Clare
#                         format
# format
# Paperback                 343
# Hardcover                 184
#                           183
# ebook                     106
# Kindle Edition             68
# Audiobook                  45
# Audio CD                   31
# Mass Market Paperback       6
# Audio                       5
# Audible Audio               4
# Library Binding             3
# MP3 CD                      3
# 創元推理文庫                      2
# Audio Cassette              1
# Broché                      1
# Grand format                1
# Klappenbroschur             1
#
#  Mindy Kaling
#                  format
# format
# Paperback            5
# ebook                5
# Audio CD             3
# Audiobook            3
#                      2
# Hardcover            2
# Audible Audio        1
# Kindle Edition       1
#
#  Veronica Roth
#                   format
# format
# Paperback           176
# Hardcover           102
#                     100
# ebook                80
# Audiobook            27
# Kindle Edition       23
# Audio CD              9
# Audible Audio         7
# Library Binding       5
# MP3 CD                2
# Nook                  2
# Audio                 1
# Flipback              1
# Nook ebook            1
# Trade Paperback       1
# Unknown Binding       1
#
#  Colleen Hoover
#                         format
# format
# Paperback                  84
#                            46
# ebook                      27
# Kindle Edition             21
# Hardcover                  12
# Audiobook                   9
# Audible Audio               4
# Audio CD                    3
# Nook                        2
# MP3 CD                      1
# Mass Market Paperback       1

# %%
af.columns = ['count']
# Out:
#                                count
# author_name   format
# Bill  Gates                       37
#               Paperback           20
#               Hardcover           15
#               Audiobook            5
#               ebook                5
# ...                              ...
# Veronica Roth Audio                1
#               Flipback             1
#               Nook ebook           1
#               Trade Paperback      1
#               Unknown Binding      1
#
# [193 rows x 1 columns]

# %%
# Group by 'author_name' and 'format' and sum the 'count' values
grouped_df = af.groupby(['author_name', 'format'])['count'].sum().unstack(fill_value=0)
grouped_df
# Out:
# format                     17 x 26  Audible Audio  Audible MP3 Download  \
# author_name
# Bill  Gates            37        0              0                     0
# Cassandra Clare       183        0              4                     0
# Colleen Hoover         46        0              4                     0
# James Patterson      1338        0             24                     1
# John Green             92        0              5                     0
# Mindy Kaling            2        0              1                     0
# Neil deGrasse Tyson    14        0              2                     0
# Rick Riordan          237        0             11                     0
# Stephen King         1175        1             57                     0
# Veronica Roth         100        0              7                     0
#
# format               Audible.com  Audio  Audio Book  Audio CD  Audio Cassette  \
# author_name
# Bill  Gates                    0      1           0         3               0
# Cassandra Clare                0      5           0        31               1
# Colleen Hoover                 0      0           0         3               0
# James Patterson                0    142           1       514               7
# John Green                     0      0           0        46               0
# Mindy Kaling                   0      0           0         3               0
# Neil deGrasse Tyson            0      1           0         6               1
# Rick Riordan                   0      5           0        73               0
# Stephen King                   1     39           0       193              82
# Veronica Roth                  0      1           0         9               0
#
# format               Audio Playaway  ...  audio  audiobook  book  ebook  \
# author_name                          ...
# Bill  Gates                       0  ...      0          0     0      5
# Cassandra Clare                   0  ...      0          0     0    106
# Colleen Hoover                    0  ...      0          0     0     27
# James Patterson                   0  ...      1          0     1    869
# John Green                        0  ...      0          0     0     64
# Mindy Kaling                      0  ...      0          0     0      5
# Neil deGrasse Tyson               0  ...      0          0     0     11
# Rick Riordan                      0  ...      0          0     0     73
# Stephen King                      1  ...      0          1     0    344
# Veronica Roth                     0  ...      0          0     0     80
#
# format               hardcover  large print  paper  paperback  جيبي  創元推理文庫
# author_name
# Bill  Gates                  0            0      0          0     0       0
# Cassandra Clare              0            0      0          0     0       2
# Colleen Hoover               0            0      0          0     0       0
# James Patterson              2            5      0          1     0       0
# John Green                   0            0      0          0     0       0
# Mindy Kaling                 0            0      0          0     0       0
# Neil deGrasse Tyson          0            0      0          0     0       0
# Rick Riordan                 0            0      0          0     0       0
# Stephen King                 0            0      2          1     1       0
# Veronica Roth                0            0      0          0     0       0
#
# [10 rows x 77 columns]

# %%
grouped_df.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.xlabel('Author Name')
plt.ylabel('Count')
plt.title('Distribution of Book Formats by Author')
plt.legend(title='Format', bbox_to_anchor=(1, 1))

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 21109 (\N{CJK UNIFIED IDEOGRAPH-5275}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20803 (\N{CJK UNIFIED IDEOGRAPH-5143}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25512 (\N{CJK UNIFIED IDEOGRAPH-63A8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 29702 (\N{CJK UNIFIED IDEOGRAPH-7406}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25991 (\N{CJK UNIFIED IDEOGRAPH-6587}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 24235 (\N{CJK UNIFIED IDEOGRAPH-5EAB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Group by 'format' and sum the 'count' values
grouped_df = af.groupby('format')['count'].sum()
grouped_df = grouped_df.sort_values(ascending=False).head(20)

# Plot the data as a bar chart
grouped_df.plot(kind='bar', figsize=(10, 6))
plt.xlabel('Format')
plt.ylabel('Total Count')
plt.title('General Distribution of Book Formats')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# ## Provide information about the general response from readers (number of fans, average rating, number of reviews, etc.), divide the authors by gender, and comment about anything eventually related to “structural bias.” You may want to have a look at the following recommended readings:

# %%
info_influent = authors_influential[['name', 'gender', 'average_rating', 'ratings_count', 'text_reviews_count',
                    'fans_count']]
info_influent.gender = info_influent.gender.apply(lambda x: 'male' if x == '' else x)
info_influent.loc[info_influent['name'] == 'Mindy Kaling', 'gender'] = 'female'
info_influent
# Out:
# <ipython-input-116-751109c3076c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   info_influent.gender = info_influent.gender.apply(lambda x: 'male' if x == '' else x)
#                        name  gender  average_rating  ratings_count  \
# 1017           Stephen King    male        4.039062       15195579
# 1161        James Patterson    male        3.980469        6514711
# 27110       Cassandra Clare  female        4.238281        7401435
# 4537           Rick Riordan    male        4.320312        9144089
# 169374        Veronica Roth  female        4.050781        5739316
# 205870       Colleen Hoover  female        4.238281        2239503
# 100166           John Green    male        4.031250        7186569
# 3818    Neil deGrasse Tyson    male        4.070312         175216
# 32358          Mindy Kaling  female        3.880859         611045
# 6397            Bill  Gates    male        3.849609           9418
#
#         text_reviews_count  fans_count
# 1017                608956      766035
# 1161                333220      317040
# 27110               416177      238560
# 4537                354145      339346
# 169374              277033      455358
# 205870              240302      356633
# 100166              358221      282537
# 3818                 16300      277850
# 32358                34482      234647
# 6397                   562      446876

# %%
import seaborn as sns
# Data analysis and visualization
sns.set(style="whitegrid")
plt.figure(figsize=(12, 6))

# Plot fan count by gender
sns.barplot(data=info_influent, x="fans_count", y="name", hue="gender", palette="husl")
plt.title("Fan Count by Author and Gender")
plt.xlabel("Fan Count")

# Show average rating by gender
plt.figure(figsize=(12, 6))
sns.boxplot(data=info_influent, x="gender", y="average_rating", palette="Set2")
plt.title("Average Rating by Gender")
plt.xlabel("Gender")
plt.ylabel("Average Rating")

# Show number of reviews by gender
plt.figure(figsize=(12, 6))
sns.boxplot(data=info_influent, x="gender", y="ratings_count", palette="Paired")
plt.title("Number of Reviews by Gender")
plt.xlabel("Gender")
plt.ylabel("Number of Reviews")

plt.show()

# %%
# 2. Gender Distribution
gender_distribution = info_influent['gender'].value_counts()
gender_distribution.plot(kind='bar', title='Gender Distribution')
# Out:
# <Axes: title={'center': 'Gender Distribution'}>

# %%
# 3. Rating Analysis
rating_by_gender = info_influent.groupby('gender')['average_rating'].mean()
rating_by_gender
# Out:
# gender
# female    4.102051
# male      4.048502
# Name: average_rating, dtype: float32

# %% [markdown]
# # RQ6

# %% [markdown]
# ## Provide the average time gap between two subsequent publications for a series of books and those not belonging to a series. What do you expect to see, and what is the actual answer to this question?

# %%
authors_influential = df.sort_values(by = 'fans_count', ascending = False)
authors_influential = authors_influential[:10]
names_influent = authors_influential['name']
df1 = df_books[df_books['author_name'].isin(names_influent)]

#Converting the dates in date-format yy-mm-dd
df1['original_publication_date'] = pd.to_datetime(df1['original_publication_date'], errors='coerce',  unit='D')
#Calculate difference between two consecutive publication years for each author
#and each book
df1 = df1.sort_values(by=['author_name', 'original_publication_date'])
df1['year_diff'] = df1.groupby('author_name')['original_publication_date'].diff().dt.days
df1['year_diff'] = df1['year_diff'].fillna(0)
df1['year_diff'] = df1['year_diff'].astype(int)
#Calculating average of year differences for books not belonging to a series
df1_not_series = df1[df1['series_name'] == '']
df1_not_series = df1_not_series.groupby('author_name')['year_diff'].mean()
df1_not_series = df1_not_series.reset_index()
df1_not_series = df1_not_series.rename(columns={'year_diff':'avg_year_diff_not_series'})
#Calculating average of year differences for books belonging to a series
df1_series = df1[df1['series_name'] != '']
df1_series = df1_series.groupby('author_name')['year_diff'].mean()
df1_series = df1_series.reset_index()
df1_series = df1_series.rename(columns={'year_diff':'avg_year_diff_series'})
#Merging the two dataframes
df1_year_diff = df1_not_series.merge(df1_series, on='author_name', how='outer')
#Plotting the results
plt.figure(figsize=(10,5))
plt.hist(df1_year_diff['avg_year_diff_not_series'], bins=10, label='Not Series')
plt.hist(df1_year_diff['avg_year_diff_series'], bins=10, label='Series')
plt.xlabel('Average year difference')
plt.ylabel('Number of authors')
plt.title('Average year difference between two subsequent publications')
plt.legend()
plt.show()
# Out:
# <ipython-input-68-7cc06b048aee>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['original_publication_date'] = pd.to_datetime(df1['original_publication_date'], errors='coerce',  unit='D')

# %%
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.set(style="whitegrid")
sns.barplot(data=df1_year_diff, x='avg_year_diff_not_series', y='author_name', label='Not Series', color='b')
sns.barplot(data=df1_year_diff, x='avg_year_diff_series', y='author_name', label='Series', color='r')
plt.xlabel('Average Days Difference')
plt.title('Average Days Difference for Top Influential Authors')
plt.legend()
plt.tight_layout()

plt.show()

# %% [markdown]
# ## For each of the authors, give a convenient plot showing how many books has the given author published UP TO a given year. Are these authors contemporary with each other? Can you notice a range of years where their production rate was higher?

# %%
def date_y(date):
    if pd.notna(date):
        return int(date.year)
    else:
        return 0

df1['publication_year'] = df1.original_publication_date.apply(date_y)

a = df1.groupby(['author_name', 'publication_year']).id.count().to_frame()
a.columns = ['count']
a = a.reset_index()

# %%
def untily(year, df):
    df = df[df.publication_year < year]
    b = df.groupby(['author_name'])['count'].sum().sort_values(ascending=False)
    b.plot(kind='bar', figsize=(10, 6))
untily(2010, a)

# %% [markdown]
# # RQ8

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import numpy as np

#It seems reasonable to assume that authors with more fans should have more
#reviews, but maybe their fans are a bit lazy. Confirm or reject this with a
#convenient statistical test or a predictive model.
data_model = df[['fans_count', 'text_reviews_count']].astype(int)
data_model.dropna(inplace=True)

x = np.array(data_model['fans_count'])
y = np.array(data_model['text_reviews_count'])

# Dividiamo i dati in un insieme di addestramento e un insieme di test (80% - 20%).
x_train, x_test, y_train, y_test = train_test_split(x.reshape(-1, 1), y, test_size=0.2, random_state=42)

# Creiamo un'istanza del modello di regressione lineare.
model = LinearRegression()
# Addestriamo il modello con i dati di addestramento.
model.fit(x_train, y_train)


# Calcoliamo il coefficiente di regressione.
coefficient = model.coef_[0]
intercept = model.intercept_

# %%
plt.scatter(data_model.fans_count, data_model.text_reviews_count)
# Calculate the corresponding y values for the line
line_y = coefficient * x + intercept

# Plot the line
plt.plot(data_model.fans_count, line_y, color='red')

# %% [markdown]
# # Bonus 1

# %% [markdown]
# Select one alternative library to Pandas (i.e., Dask, Polar, Vaex, Datatable, etc.), upload authors.json dataset, and filter authors with at least 100 reviews. Do the same using Pandas and compare performance in terms of milliseconds.

# %%
import time

# Set the chunk size
chunk_size = 100_000

# Create an empty DataFrame to store the filtered results
filtered_authors_pandas = pd.DataFrame()

# Measure the start time
start_time = time.time()

# Load the dataset in chunks
for chunk in pd.read_json(filename, lines=True, chunksize=chunk_size):
    # filter each chunk
    filtered_chunk = chunk[chunk['text_reviews_count'] >= 100]
    filtered_authors_pandas = pd.concat([filtered_authors_pandas, filtered_chunk])

# compute execcution time
pandas_exec_time = time.time() - start_time

print("Pandas Execution Time:", pandas_exec_time, "seconds")
# Out:
# Pandas Execution Time: 22.872453451156616 seconds

# %%
#Pandas Execution Time: 244s

# %%
import dask.dataframe as dd

# Load the dataset
df = dd.read_json(filename, blocksize='128MB')

# Measure the start time
start_time = time.time()

# Filter authors with at least 100 reviews
filtered_authors_dask = df[df['text_reviews_count'] >= 100].compute()

dask_exec_time = time.time() - start_time

print("Dask Execution Time:", dask_exec_time, "seconds")
# Out:
# Dask Execution Time: 28.63842749595642 seconds

# %%
#Dask Execution Time: 208s

# %%
print("Difference in execution time", (pandas_exec_time - dask_exec_time)*1000)
# Out:
# Difference in execution time -5765.974044799805

# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.0.tar.gz (316.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.9/316.9 MB 966.8 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.0-py2.py3-none-any.whl size=317425344 sha256=4661769ee43755aeb811ea657ee4f8becab1f84edaa8f2f25001d803e82ade2c
#   Stored in directory: /root/.cache/pip/wheels/41/4e/10/c2cf2467f71c678cfc8a6b9ac9241e5e44a01940da8fbb17fc
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.0

# %%
#Use pyspark for books.json file to avoid ram overload
from pyspark import SparkContext
from pyspark.sql import SparkSession

#Set pyspark parameters
sc = SparkContext("local", "YourAppName")
spark = SparkSession(sc)

#Read authors.json file
a = spark.read.json(filename)
#Rename the column to allow later the merge
a = a.withColumnRenamed("id", "author_id")
#Read books.json file
b =  spark.read.json(filename1)

# Merge the two dataframes performing a left join on 'b'
# By doig so you are including all rows from the 'b' dataframe and the matching rows from the 'a' dataframe
# Where the rows of 'a' don't match, the corresponding row will be fileld with null values
merged_df = b.join(a, "author_id", "left")

# Now we just need to count how many values of a consistent column coming from 'a', for example 'names', are null
unmatched = merged_df.filter(merged_df.name.isNull()).count()
print(f"Number of books without a matching author: {unmatched}")
print(merged_df.count())
# Out:
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/usr/local/lib/python3.10/dist-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/usr/lib/python3.10/socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-6a1ede22b133> in <cell line: 6>()
#       4
#       5 #Set pyspark parameters
# ----> 6 sc = SparkContext("local", "YourAppName")
#       7 spark = SparkSession(sc)
#       8
#
# /usr/local/lib/python3.10/dist-packages/pyspark/context.py in __init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     201         SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     202         try:
# --> 203             self._do_init(
#     204                 master,
#     205                 appName,
#
# /usr/local/lib/python3.10/dist-packages/pyspark/context.py in _do_init(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     294
#     295         # Create the Java SparkContext through Py4J
# --> 296         self._jsc = jsc or self._initialize_context(self._conf._jconf)
#     297         # Reset the SparkConf to the one actually used by the SparkContext in JVM.
#     298         self._conf = SparkConf(_jconf=self._jsc.sc().conf())
#
# /usr/local/lib/python3.10/dist-packages/pyspark/context.py in _initialize_context(self, jconf)
#     419         """
#     420         assert self._jvm is not None
# --> 421         return self._jvm.JavaSparkContext(jconf)
#     422
#     423     @classmethod
#
# /usr/local/lib/python3.10/dist-packages/py4j/java_gateway.py in __call__(self, *args)
#    1584             proto.END_COMMAND_PART
#    1585
# -> 1586         answer = self._gateway_client.send_command(command)
#    1587         return_value = get_return_value(
#    1588             answer, self._gateway_client, None, self._fqn)
#
# /usr/local/lib/python3.10/dist-packages/py4j/java_gateway.py in send_command(self, command, retry, binary)
#    1036         connection = self._get_connection()
#    1037         try:
# -> 1038             response = connection.send_command(command)
#    1039             if binary:
#    1040                 return response, self._create_connection_guard(connection)
#
# /usr/local/lib/python3.10/dist-packages/py4j/clientserver.py in send_command(self, command)
#     509         try:
#     510             while True:
# --> 511                 answer = smart_decode(self.stream.readline()[:-1])
#     512                 logger.debug("Answer received: {0}".format(answer))
#     513                 # Happens when a the other end is dead. There might be an empty
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# Sample DataFrames
books_data = {
    'book': ['Book1', 'Book2', 'Book4'],
    'author_id': [101, 102, 104]
}

authors_data = {
    'author': ['AuthorA', 'AuthorB', 'AuthorC'],
    'author_id': [101, 102, 103]
}

# Create DataFrames
books_df = pd.DataFrame(books_data)
authors_df = pd.DataFrame(authors_data)

# Merge the DataFrames based on "author_id" using an outer join
merged_df = books_df.merge(authors_df, on="author_id", how="outer")
print(merged_df)

# Count the number of rows where the author information is missing
books_without_author = merged_df[merged_df['author'].isna()]


# Get the count of books without a matching author
count_books_without_author = len(books_without_author)

print(f"Number of books without a matching author: {count_books_without_author}")
# Out:
#     book  author_id   author
# 0  Book1        101  AuthorA
# 1  Book2        102  AuthorB
# 2  Book4        104      NaN
# 3    NaN        103  AuthorC
# Number of books without a matching author: 1

# %% [markdown]
# # Bonus 2

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans, MiniBatchKMeans

# Create a CountVectorizer
vectorizer = CountVectorizer()
# Determine the number of clusters, according to wikipedia and other sources there are 4
# main literary genres (fiction, non-fiction, poetry, drama)
num_clusters = 4
import io
import re

chunk_size = 100000
res = []
for chunk in pd.read_json(filename, lines=True, chunksize=chunk_size):
    for i in chunk['about']:
        if i != '':
            # Create a file handle from the input string
            file_handle = io.StringIO(i)
            soup = BeautifulSoup(file_handle, 'html.parser')
            # Get the cleaned text
            cleaned_text = soup.get_text()
            # Remove leading and trailing whitespaces
            cleaned_text = cleaned_text.strip()
            cleaned_text = cleaned_text.lower()

            # Remove special characters, punctuation, and extra whitespaces
            cleaned_text = re.sub(r'[^a-zA-Z\s]', '', cleaned_text)

            # Remove extra whitespaces
            cleaned_text = ' '.join(cleaned_text.split())
            res.append(cleaned_text)
df = pd.DataFrame(res, columns=['about'])
descriptions_bow = vectorizer.fit_transform(df['about'])
kmeans = MiniBatchKMeans(n_clusters=num_clusters, random_state=0)
kmeans.fit(descriptions_bow)
df['genre'] = kmeans.labels_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
for i in range(10):
    print(df.iloc[i])
# Out:
# about    douglas nol adams was an english author comic ...
# genre                                                    0
# Name: 0, dtype: object
# about    william mcguire bill bryson obe frs was born i...
# genre                                                    0
# Name: 1, dtype: object
# about    jude fisher is the pseudonym for jane johnson ...
# genre                                                    3
# Name: 2, dtype: object
# about    james hamiltonpatersons work has been translat...
# genre                                                    1
# Name: 3, dtype: object
# about    mark andrew watson born february is an english...
# genre                                                    3
# Name: 4, dtype: object
# about    edith newbold jones was born into such wealth ...
# genre                                                    0
# Name: 5, dtype: object
# about    httpsearchbarnesandnoblecombookluther butler l...
# genre                                                    3
# Name: 6, dtype: object
# about    although he was never a dedicated student paul...
# genre                                                    3
# Name: 7, dtype: object
# about    dale peck born on long island new york is an a...
# genre                                                    1
# Name: 8, dtype: object
# about    angela knight is an american author of mostly ...
# genre                                                    2
# Name: 9, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfTransformer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from bs4 import BeautifulSoup
import io
import re
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
# Define genre keywords or adjectives
genre_keywords = {
    'fiction': ['fiction', 'mystery', 'romance', 'mythology', 'fantasy', 'dystopian', 'horror'],
    'non-fiction': ['nonfiction', 'inform' 'textbooks', 'essays', 'autobiography', 'biography' 'research'],
    'poetry': ['poem', 'literature', 'epic', 'lyric' 'poetry', 'poet', 'poetic'],
    'drama': ['drama', 'audience', 'actors', 'characters', 'acts', 'tragedy', 'comedy']
}

# Create a TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

#Use tf-idf instead of the raw frequencies of occurrence of a token in a given document
# to scale down the impact of tokens that occur very frequently

chunk_size = 100000
res = []
for chunk in pd.read_json(filename, lines=True, chunksize=chunk_size):
    for i in chunk['about']:
        if i != '':
            # Create a file handle from the input string
            file_handle = io.StringIO(i)
            soup = BeautifulSoup(file_handle, 'html.parser')
            # Get the cleaned text
            cleaned_text = soup.get_text()
            # Remove leading and trailing whitespaces
            cleaned_text = cleaned_text.strip()
            cleaned_text = cleaned_text.lower()

            # Remove special characters, punctuation, and extra whitespaces
            cleaned_text = re.sub(r'[^a-zA-Z\s]', '', cleaned_text)

            # Remove extra whitespaces
            cleaned_text = ' '.join(cleaned_text.split())
            res.append(cleaned_text)
df = pd.DataFrame(res, columns=['about'])
# Transform descriptions and keywords into TF-IDF vectors
#description_tfidf = tfidf_vectorizer.fit_transform(df['about'])
#genre_tfidf = {genre: tfidf_vectorizer.fit_transform(keywords) for genre, keywords in genre_keywords.items()}

vectorizer = CountVectorizer().fit(df['about'])
genre_bag = {genre: vectorizer.transform(keywords) for genre, keywords in genre_keywords.items()}


# Classify descriptions based on cosine similarity
def classify_description(description):
    #similarity_scores = {genre: cosine_similarity(description_tfidf, genre_tfidf[genre], dense_output=False).mean() for genre in genre_keywords}
    similarity_scores = {genre: cosine_similarity(vectorizer.transform([description]), bag)[0][0] for genre, bag in genre_bag.items()}
    print(max(similarity_scores, key=similarity_scores.get))
    return max(similarity_scores, key=similarity_scores.get)

# Add genre labels to the DataFrame
df['genre'] = df['about'].apply(classify_description)
# Out:
# Output streaming troncato alle ultime 5000 righe.
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# drama
# fiction
# fiction
# drama
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# non-fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# poetry
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# poetry
# fiction
# non-fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# drama
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction
# fiction

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00cf07b74dcd> in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %% [markdown]
# # AWS

# %%
#scp -i "mykeypair.pem" list.json ubuntu@ec2-18-232-83-254.compute-1.amazonaws.com:
#scp -i mykeypair.pem AWSQ.py ubuntu@ec2-67-202-18-229.compute-1.amazonaws.com:
#ssh -i "mykeypair.pem" ubuntu@ec2-54-198-218-186.compute-1.amazonaws.com

# By running the python code using the magic command '%%timeit' in a jupyter notebook,
# we get:
# 26.4 s ± 5.96 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
# This is better than simply using tge time.start, time.end functions since the code is rune multiple times
# and you get an average of the running time

#time python3 AWSQ.py

#real    0m34.116s
#user    0m27.506s
#sys     0m1.115s

# to dwonload from bucket aws s3 cp s3://admlab1bucket/list.json .

# %% [markdown]
# ![Screenshot 2023-10-30 095844.png](data:image/png;base64,...)
